# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os

import sys
sys.path.insert(0, '/Users/ageller/VISUALIZATIONS/Firefly')
sys.path.insert(0,'/Users/agurvich/research/repos/firefly/src')
from firefly.data_reader import FIREreader,SimpleFIREreader

from firefly.data_reader import Octree
from abg_python.galaxy.gal_utils import Galaxy
galaxy = Galaxy('m12b_res57000',600)
# Out:
# palettable colormaps are not installed
# don't have phil's colormaps
# Couldn't find a metadata file... for
#  Metadata object at /Users/agurvich/scratch/data/metal_diffusion/m12b_res57000/metadata/meta_Galaxy_600.hdf5
# Tracing the rockstar halo files with fancy:True and None Gyr smoothing.
# No rstar 1/2 in halo or metadata files, we will need to calculate it ourselves.

# %%
center = galaxy.scom#np.zeros(3)#galaxy.scom+ [-39,-168,189]
reader = FIREreader(
    galaxy.snapdir,
    galaxy.snapnum,
    ptypes=[0,4],
    decimation_factors = [1,1],
    fields = ['Temperature','Masses','AgeGyr'],
    logFlags = [1,0,0],
    clean_JSONdir=True,
    write_startup=True)
reader.loadData(com=center)
# Out:
# JSONdir is None, defaulting to /Users/agurvich/research/repos/firefly/src/firefly/static/data/Data
# Loading ptype 4
# Loading ptype 0
# array([PartType0 - 6225729/6225729 particles - 3 tracked fields,
#        PartType4 - 3264723/3264723 particles - 3 tracked fields],
#       dtype=object)

# %%
reader.settings['color']['PartType0']=[1,0,0,1]
reader.settings['color']['PartType4']=[0,0,1,1]

reader.settings['sizeMult']['PartType0']=1
reader.settings['sizeMult']['PartType4']=1
reader.dumpSettingsToJSON()
# Out:
# ('/Users/agurvich/research/repos/firefly/src/firefly/static/data/Data/DataSettings.json',
#  '/Users/agurvich/research/repos/firefly/src/firefly/static/data/Data/DataSettings.json')

# %%
reader.createOctrees([True,False],npart_min_node=1e4,npart_max_node=1e5)
# Out:
# Bulding octree of 6223874 points
# 0.00%	0.16%	0.32%	0.48%	0.64%	0.80%	0.96%	1.12%	1.29%	1.45%	1.61%	1.77%	1.93%	2.09%	2.25%	2.41%	2.57%	2.73%	2.89%	3.05%	3.21%	3.37%	3.53%	3.70%	3.86%	4.02%	4.18%	4.34%	4.50%	4.66%	4.82%	4.98%	5.14%	5.30%	5.46%	5.62%	5.78%	5.94%	6.11%	6.27%	6.43%	6.59%	6.75%	6.91%	7.07%	7.23%	7.39%	7.55%	7.71%	7.87%	8.03%	8.19%	8.35%	8.52%	8.68%	8.84%	9.00%	9.16%	9.32%	9.48%	9.64%	9.80%	9.96%	10.12%	10.28%	10.44%	10.60%	10.76%	10.93%	11.09%	11.25%	11.41%	11.57%	11.73%	11.89%	12.05%	12.21%	12.37%	12.53%	12.69%	12.85%	13.01%	13.18%	13.34%	13.50%	13.66%	13.82%	13.98%	14.14%	14.30%	14.46%	14.62%	14.78%	14.94%	15.10%	15.26%	15.42%	15.59%	15.75%	15.91%	16.07%	16.23%	16.39%	16.55%	16.71%	16.87%	17.03%	17.19%	17.35%	17.51%	17.67%	17.83%	18.00%	18.16%	18.32%	18.48%	18.64%	18.80%	18.96%	19.12%	19.28%	19.44%	19.60%	19.76%	19.92%	20.08%	20.24%	20.41%	20.57%	20.73%	20.89%	21.05%	21.21%	21.37%	21.53%	21.69%	21.85%	22.01%	22.17%	22.33%	22.49%	22.65%	22.82%	22.98%	23.14%	23.30%	23.46%	23.62%	23.78%	23.94%	24.10%	24.26%	24.42%	24.58%	24.74%	24.90%	25.06%	25.23%	25.39%	25.55%	25.71%	25.87%	26.03%	26.19%	26.35%	26.51%	26.67%	26.83%	26.99%	27.15%	27.31%	27.47%	27.64%	27.80%	27.96%	28.12%	28.28%	28.44%	28.60%	28.76%	28.92%	29.08%	29.24%	29.40%	29.56%	29.72%	29.88%	30.05%	30.21%	30.37%	30.53%	30.69%	30.85%	31.01%	31.17%	31.33%	31.49%	31.65%	31.81%	31.97%	32.13%	32.29%	32.46%	32.62%	32.78%	32.94%	33.10%	33.26%	33.42%	33.58%	33.74%	33.90%	34.06%	34.22%	34.38%	34.54%	34.71%	34.87%	35.03%	35.19%	35.35%	35.51%	35.67%	35.83%	35.99%	36.15%	36.31%	36.47%	36.63%	36.79%	36.95%	37.12%	37.28%	37.44%	37.60%	37.76%	37.92%	38.08%	38.24%	38.40%	38.56%	38.72%	38.88%	39.04%	39.20%	39.36%	39.53%	39.69%	39.85%	40.01%	40.17%	40.33%	40.49%	40.65%	40.81%	40.97%	41.13%	41.29%	41.45%	41.61%	41.77%	41.94%	42.10%	42.26%	42.42%	42.58%	42.74%	42.90%	43.06%	43.22%	43.38%	43.54%	43.70%	43.86%	44.02%	44.18%	44.35%	44.51%	44.67%	44.83%	44.99%	45.15%	45.31%	45.47%	45.63%	45.79%	45.95%	46.11%	46.27%	46.43%	46.59%	46.76%	46.92%	47.08%	47.24%	47.40%	47.56%	47.72%	47.88%	48.04%	48.20%	48.36%	48.52%	48.68%	48.84%	49.00%	49.17%	49.33%	49.49%	49.65%	49.81%	49.97%	50.13%	50.29%	50.45%	50.61%	50.77%	50.93%	51.09%	51.25%	51.41%	51.58%	51.74%	51.90%	52.06%	52.22%	52.38%	52.54%	52.70%	52.86%	53.02%	53.18%	53.34%	53.50%	53.66%	53.82%	53.99%	54.15%	54.31%	54.47%	54.63%	54.79%	54.95%	55.11%	55.27%	55.43%	55.59%	55.75%	55.91%	56.07%	56.24%	56.40%	56.56%	56.72%	56.88%	57.04%	57.20%	57.36%	57.52%	57.68%	57.84%	58.00%	58.16%	58.32%	58.48%	58.65%	58.81%	58.97%	59.13%	59.29%	59.45%	59.61%	59.77%	59.93%	60.09%	60.25%	60.41%	60.57%	60.73%	60.89%	61.06%	61.22%	61.38%	61.54%	61.70%	61.86%	62.02%	62.18%	62.34%	62.50%	62.66%	62.82%	62.98%	63.14%	63.30%	63.47%	63.63%	63.79%	63.95%	64.11%	64.27%	64.43%	64.59%	64.75%	64.91%	65.07%	65.23%	65.39%	65.55%	65.71%	65.88%	66.04%	66.20%	66.36%	66.52%	66.68%	66.84%	67.00%	67.16%	67.32%	67.48%	67.64%	67.80%	67.96%	68.12%	68.29%	68.45%	68.61%	68.77%	68.93%	69.09%	69.25%	69.41%	69.57%	69.73%	69.89%	70.05%	70.21%	70.37%	70.53%	70.70%	70.86%	71.02%	71.18%	71.34%	71.50%	71.66%	71.82%	71.98%	72.14%	72.30%	72.46%	72.62%	72.78%	72.94%	73.11%	73.27%	73.43%	73.59%	73.75%	73.91%	74.07%	74.23%	74.39%	74.55%	74.71%	74.87%	75.03%	75.19%	75.35%	75.52%	75.68%	75.84%	76.00%	76.16%	76.32%	76.48%	76.64%	76.80%	76.96%	77.12%	77.28%	77.44%	77.60%	77.77%	77.93%	78.09%	78.25%	78.41%	78.57%	78.73%	78.89%	79.05%	79.21%	79.37%	79.53%	79.69%	79.85%	80.01%	80.18%	80.34%	80.50%	80.66%	80.82%	80.98%	81.14%	81.30%	81.46%	81.62%	81.78%	81.94%	82.10%	82.26%	82.42%	82.59%	82.75%	82.91%	83.07%	83.23%	83.39%	83.55%	83.71%	83.87%	84.03%	84.19%	84.35%	84.51%	84.67%	84.83%	85.00%	85.16%	85.32%	85.48%	85.64%	85.80%	85.96%	86.12%	86.28%	86.44%	86.60%	86.76%	86.92%	87.08%	87.24%	87.41%	87.57%	87.73%	87.89%	88.05%	88.21%	88.37%	88.53%	88.69%	88.85%	89.01%	89.17%	89.33%	89.49%	89.65%	89.82%	89.98%	90.14%	90.30%	90.46%	90.62%	90.78%	90.94%	91.10%	91.26%	91.42%	91.58%	91.74%	91.90%	92.06%	92.23%	92.39%	92.55%	92.71%	92.87%	93.03%	93. ...
# adding 1855 'outliers' to root node's buffer.
# 0 11	100 3264	200 7420

# %%
reader.max_npart_per_file = 1e5
reader.particleGroups[1].decimation_factor = 100
reader.writeToDisk()
# Out:
# Writing aggregate/meta data to octree.json
# 0.00% <>	1.27% <4>	2.53% <0>	3.80% <344>	5.06% <52>	6.33% <7>	7.59% <2>	8.86% <077>	10.13% <166>	11.39% <3444>	12.66% <437>	13.92% <5222>	15.19% <7000>	16.46% <34444>	17.72% <61111>	18.99% <63>	20.25% <52222>	21.52% <70000>	22.78% <433333>	24.05% <30>	25.32% <166666>	26.58% <3403472>	27.85% <344064>	29.11% <4373>	30.38% <4333333>	31.65% <257>	32.91% <6151>	34.18% <3444444>	35.44% <526>	36.71% <700000>	37.97% <43377>	39.24% <6133>	40.51% <65>	41.77% <3405>	43.04% <34036>	44.30% <0714>	45.57% <7004>	46.84% <43335>	48.10% <05>	49.37% <6135>	50.63% <34407>	51.90% <1662>	53.16% <0717>	54.43% <0713>	55.70% <704>	56.96% <43373>	58.23% <34442>	59.49% <4376>	60.76% <34403>	62.03% <611115>	63.29% <5223>	64.56% <34033>	65.82% <6313>	67.09% <0716>	68.35% <07773>	69.62% <611113>	70.89% <61113>	72.15% <07776>	73.42% <255551>	74.68% <34445>	75.95% <27>	77.22% <166662>	78.48% <340346>	79.75% <433337>	81.01% <25554>	82.28% <52220>	83.54% <164>	84.81% <16667>	86.08% <1664>	87.34% <522220>	88.61% <4374>	89.87% <432>	91.14% <07771>	92.41% <4370>	93.67% <1660>	94.94% <6310>	96.20% <076>	97.47% <2553>	98.73% <0754>	done!
# ''

# %% [markdown]
# -------

# %%
from firefly.data_reader import ArrayReader
# Load your data. Here we're creating random data.
coords = np.random.randn( 20000, 3 )
fields = np.random.random(size=coords[:,0].size)
my_arrayReader = ArrayReader(
    coords,
    fields=fields,
    write_jsons_to_disk=True)
# Out:
# JSONdir is None, defaulting to /Users/agurvich/research/repos/firefly/src/firefly/static/data/Data
# Importing existing settings from /Users/agurvich/research/repos/firefly/src/firefly/static/data/Data/DataSettings.json
# Make sure each field_array (1) has a field_filter_flag (0), assuming True.
# Make sure each field_array (1) has a field_colormap_flag (0), assuming True.
# Make sure each field_array (1) has a field_radius_flag (0), assuming False.
# KeyboardInterrupt

# %%
octree = reader.particleGroups[0].octree

root = octree.nodes['']
child = octree.nodes['4']

# %%
root.center-root.width/2
# Out:
# array([-9468.1  , -8766.78 , -8872.656], dtype=float32)

# %%
root.center
# Out:
# array([-1825.021 , -1123.702 , -1229.5784], dtype=float32)

# %%
child.fields
# Out:
# array([ 1.00252092e+01,  1.16980360e-02, -1.09850803e+11, -7.46773799e+10,
#        -2.86814218e+10])

# %%
child.center-child.width/2
# Out:
# array([-9468.09912109, -8766.78015137, -1229.57836914])

# %%
import time

# %%
init_time = time.time()
node_list = octree.buildOctree()
print()
print(time.time()-init_time,'s elapsed')
# Out:
# 0.00%	0.79%	1.59%	2.38%	3.17%	3.97%	4.76%	5.56%	6.35%	7.14%	7.94%	8.73%	9.52%	10.32%	11.11%	11.91%	12.70%	13.49%	14.29%	15.08%	15.87%	16.67%	17.46%	18.25%	19.05%	19.84%	20.64%	21.43%	22.22%	23.02%	23.81%	24.60%	25.40%	26.19%	26.98%	27.78%	28.57%	29.37%	30.16%	30.95%	31.75%	32.54%	33.33%	34.13%	34.92%	35.72%	36.51%	37.30%	38.10%	38.89%	39.68%	40.48%	41.27%	42.06%	42.86%	43.65%	44.45%	45.24%	46.03%	46.83%	47.62%	48.41%	49.21%	50.00%	50.80%	51.59%	52.38%	53.18%	53.97%	54.76%	55.56%	56.35%	57.14%	57.94%	58.73%	59.53%	60.32%	61.11%	61.91%	62.70%	63.49%	64.29%	65.08%	65.87%	66.67%	67.46%	68.26%	69.05%	69.84%	70.64%	71.43%	72.22%	73.02%	73.81%	74.61%	75.40%	76.19%	76.99%	77.78%	78.57%	79.37%	80.16%	80.95%	81.75%	82.54%	83.34%	84.13%	84.92%	85.72%	86.51%	87.30%	88.10%	88.89%	89.69%	90.48%	91.27%	92.07%	92.86%	93.65%	94.45%	95.24%	96.03%	96.83%	97.62%	98.42%	99.21%
# 29.118792057037354 s elapsed

# %%
octree.nodes['52222050']
# Out:
# OctNode(52222050):2143 points - 4 fields

# %%
# !cat test.json
# Out:
# [{"2": 1}, {"3": 2}]

# %%
import json
arr = [{2:1},{3:2}]
with open('test.json', 'w') as f:
    json.dump(arr, f)

# %%
octree.field_names = list(octree.field_names)

# %%
np.sum([node.buffer_size for node in foo[0]])
# Out:
# 9949

# %%
len(sorted_node_list)
# Out:
# 5229

# %%
break_index
# Out:
# 4569

# %%
foo[-1]
# Out:
# array([OctNode(5222211):27 points - 4 fields,
#        OctNode(4766):27 points - 4 fields,
#        OctNode(765):27 points - 4 fields,
#        OctNode(460):27 points - 4 fields,
#        OctNode(43333146):26 points - 4 fields,
#        OctNode(43333113):26 points - 4 fields,
#        OctNode(56737):26 points - 4 fields,
#        OctNode(4764):26 points - 4 fields,
#        OctNode(7000005150):25 points - 4 fields,
#        OctNode(52222057):25 points - 4 fields,
#        OctNode(43333275):25 points - 4 fields,
#        OctNode(43333147):25 points - 4 fields,
#        OctNode(5222020):25 points - 4 fields,
#        OctNode(647):25 points - 4 fields,
#        OctNode(105):25 points - 4 fields,
#        OctNode(522223422):24 points - 4 fields,
#        OctNode(522223420):24 points - 4 fields,
#        OctNode(52222267):24 points - 4 fields,
#        OctNode(52222064):24 points - 4 fields,
#        OctNode(52222047):24 points - 4 fields,
#        OctNode(4333131):24 points - 4 fields,
#        OctNode(7000004356):23 points - 4 fields,
#        OctNode(433333713):23 points - 4 fields,
#        OctNode(433330371):23 points - 4 fields,
#        OctNode(43333377):23 points - 4 fields,
#        OctNode(43333277):23 points - 4 fields,
#        OctNode(43333033):23 points - 4 fields,
#        OctNode(7000013):23 points - 4 fields,
#        OctNode(5222215):23 points - 4 fields,
#        OctNode(753):23 points - 4 fields,
#        OctNode(5222236043):22 points - 4 fields,
#        OctNode(522223423):22 points - 4 fields,
#        OctNode(70000065):22 points - 4 fields,
#        OctNode(52222266):22 points - 4 fields,
#        OctNode(52222046):22 points - 4 fields,
#        OctNode(43333366):22 points - 4 fields,
#        OctNode(43333022):22 points - 4 fields,
#        OctNode(5222231):22 points - 4 fields,
#        OctNode(5645):22 points - 4 fields,
#        OctNode(3252):22 points - 4 fields,
#        OctNode(541):22 points - 4 fields,
#        OctNode(150):22 points - 4 fields,
#        OctNode(6111115144):21 points - 4 fields,
#        OctNode(522223601):21 points - 4 fields,
#        OctNode(43333364):21 points - 4 fields,
#        OctNode(7133):21 points - 4 fields,
#        OctNode(672):21 points - 4 fields,
#        OctNode(611111404):20 points - 4 fields,
#        OctNode(522222711):20 points - 4 fields,
#        OctNode(522222623):20 points - 4 fields,
#        OctNode(522220507):20 points - 4 fields,
#        OctNode(522220504):20 points - 4 fields,
#        OctNode(61111163):20 points - 4 fields,
#        OctNode(52222003):20 points - 4 fields,
#        OctNode(43333032):20 points - 4 fields,
#        OctNode(7000011):20 points - 4 fields,
#        OctNode(5222024):20 points - 4 fields,
#        OctNode(4333130):20 points - 4 fields,
#        OctNode(2070):20 points - 4 fields,
#        OctNode(5222226373):19 points - 4 fields,
#        OctNode(522220505):19 points - 4 fields,
#        OctNode(70000044):19 points - 4 fields,
#        OctNode(61111055):19 points - 4 fields,
#        OctNode(61111012):19 points - 4 fields,
#        OctNode(52222055):19 points - 4 fields,
#        OctNode(4333134):19 points - 4 fields,
#        OctNode(1755):19 points - 4 fields,
#        OctNode(700000510):18 points - 4 fields,
#        OctNode(522222505):18 points - 4 fields,
#        OctNode(70000073):18 points - 4 fields,
#        OctNode(5222233):18 points - 4 fields,
#        OctNode(3577):18 points - 4 fields,
#        OctNode(627):18 points - 4 fields,
#        OctNode(522223623):17 points - 4 fields,
#        OctNode(61111011):17 points - 4 fields,
#        OctNode(52222264):17 points - 4 fields,
#        OctNode(52222011):17 points - 4 fields,
#        OctNode(43331330):17 points - 4 fields,
#        OctNode(4333135):17 points - 4 fields,
#        OctNode(5375):17 points - 4 fields,
#        OctNode(624):17 points - 4 fields,
#        OctNode(5222236263):16 points - 4 fields,
#        OctNode(700000503):16 points - 4 fields,
#        OctNode(61111056):16 points - 4 fields,
#        OctNode(52222164):16 points - 4 fields,
#        OctNode(43333276):16 points - 4 fields,
#        OctNode(4154):16 points - 4 fields,
#        OctNode(736):16 points - 4 fields,
#        OctNode(514):16 points - 4 fields,
#        OctNode(7000005154):15 points - 4 fields,
#        OctNode(5222236040):15 points - 4 fields,
#        OctNode(522221622):15 points - 4 fields,
#        OctNode(52222012):15 points - 4 fields,
#        OctNode(52222010):15 points - 4 fields,
#        OctNode(4104):15 points - 4 fields,
#        OctNode(763):15 points - 4 fields,
#        OctNode(735):15 points - 4 fields,
#        OctNode(5222227353):14 points - 4 fields,
#        OctNode(611111716):14 points - 4 fields,
#        OctNode(522223664):14 points - 4 fields,
#        OctNode(522222622):14 points - 4 fields,
#        OctNode(522222531):14 points - 4 fields,
#        OctNode(433333606):14 points - 4 fields,
#        OctNode(433332736):14 points - 4 fields,
#        OctNode(61111356):14 points - 4 fields,
#        OctNode(6546):14 points - 4 fields,
#        OctNode(5311):14 points - 4 fields,
#        OctNode(4524):14 points - 4 fields,
#        OctNode(406):14 points - 4 fields,
#        OctNode(5222236041):13 points - 4 fields,
#        OctNode(611111406):13 points - 4 fields,
#        OctNode(522223603):13 points - 4 fields,
#        OctNode(433333626):13 points - 4 fields,
#        OctNode(433330372):13 points - 4 fields,
#        OctNode(43333212):13 points - 4 fields,
#        OctNode(642):13 points - 4 fields,
#        OctNode(522222601):12 points - 4 fields,
#        OctNode(61111054):12 points - 4 fields,
#        OctNode(43333213):12 points - 4 fields,
#        OctNode(43333211):12 points - 4 fields,
#        OctNode(43333076):12 points - 4 fields,
#        OctNode(5705):12 points - 4 fields,
#        OctNode(371):12 points - 4 fields,
#        OctNode(153):12 points - 4 fields,
#        OctNode(135):12 points - 4 fields,
#        OctNode(103):12 points - 4 fields,
#        OctNode(4333337356):11 points - 4 fields,
#        OctNode(611111722):11 points - 4 fields,
#        OctNode(522222602):11 points - 4 fields,
#        OctNode(43333256):11 points - 4 fields,
#        OctNode(5315):11 points - 4 fields,
#        OctNode(372):11 points - 4 fields,
#        OctNode(522222603):10 points - 4 fields,
#        OctNode(433333624):10 points - 4 fields,
#        OctNode(43333074):10 points - 4 fields,
#        OctNode(674):10 points - 4 fields,
#        OctNode(260):10 points - 4 fields,
#        OctNode(206):10 points - 4 fields,
#        OctNode(012):10 points - 4 fields,
#        OctNode(7527):9 points - 4 fields,
#        OctNode(2400):9 points - 4 fields,
#        OctNode(1751):9 points - 4 fields,
#        OctNode(327):9 points - 4 fields, OctNode(042):9 points - 4 fields,
#        OctNode(5222226375):8 points - 4 fields,
#        OctNode(522222620):8 points - 4 fields,
#        OctNode(522222533):8 points - 4 fields,
#        OctNode(61111144):8 points - 4 fields,
#        OctNode(43333020):8 points - 4 fields,
#        OctNode(43331334):8 points - 4 fields,
#        OctNode(7137):8 points - 4 fields,
#        OctNode(203):8 points - 4 fields, OctNode(021):8 points - 4 fields,
#        OctNode(014):8 points - 4 fields,
#        OctNode(7000006145):7 points - 4 fields,
#        OctNode(6111115146):7 points - 4 fields,
#        OctNode(522223666):7 points - 4 fields,
#        OctNode(522223621):7 points - 4 fields,
#        OctNode(43333254):7 points - 4 fields,
#        OctNode(43333233):7 points - 4 fields,
#        OctNode(43333230):7 points - 4 fields,
#        OctNode(43333210):7 points - 4 fields,
#        OctNode(3011):7 points - 4 fields,
#        OctNode(317):7 points - 4 fields, OctNode(312):7 points - 4 fields,
#        OctNode(130):7 points - 4 fields, OctNode(041):7 points - 4 fields,
#        OctNode(024):7 points - 4 fields,
#        OctNode(7000006146):6 points - 4 fields,
#        OctNode(61111010):6 points - 4 fields,
#        OctNode(43333123):6 points - 4 fields,
#        OctNode(230):6 points - 4 fields,
#        OctNode(6111115145):5 points - 4 fields,
#        OctNode(433332737):5 points - 4 fields,
#        OctNode(52222165):5 points - 4 fields,
#        OctNode(43333274):5 points - 4 fields,
#        OctNode(3573):5 points - 4 fields,
#        OctNode(263):5 points - 4 fields,
#        OctNode(7000006144):4 points - 4 fields,
#        OctNode(7000004275):4 points - 4 fields,
#        OctNode(5222226376):4 points - 4 fields,
#        OctNode(5222226354):4 points - 4 fields,
#        OctNode(4333337354):4 points - 4 fields,
#        OctNode(61111013):4 points - 4 fields,
#        OctNode(52222013):4 points - 4 fields,
#        OctNode(43333232):4 points - 4 fields,
#        OctNode(321):4 points - 4 fields,
#        OctNode(7000006147):3 points - 4 fields,
#        OctNode(7000004277):3 points - 4 fields,
#        OctNode(5222226374):3 points - 4 fields,
#        OctNode(5222226356):3 points - 4 fields,
#        OctNode(43333231):3 points - 4 fields,
#        OctNode(43333122):3 points - 4 fields,
#        OctNode(2402):3 points - 4 fields,
#        OctNode(236):3 points - 4 fields,
#        OctNode(5222226377):2 points - 4 fields,
#        OctNode(5222226355):2 points - 4 fields,
#        OctNode(5222226257):2 points - 4 fields,
#        OctNode(5222226254):2 points - 4 fields,
#        OctNode(433330373):2 points - 4 fields,
#        OctNode(6256):2 points - 4 fields,
#        OctNode(6111115147):1 points - 4 fields,
#        OctNode(5222226357):1 points - 4 fields,
#        OctNode(5222226256):1 points - 4 fields,
#        OctNode(5222226255):1 points - 4 fields,
#        OctNode(4333337355):1 points - 4 fields,
#        OctNode(522223667):1 points - 4 fields,
#        OctNode(3253):1 points - 4 fields,
#        OctNode(3013):1 points - 4 fields,
#        OctNode(1071):1 points - 4 fields], dtype=object)

# %%
for node in octree.node_list[::-1]:
    if hasattr(node,'buffer_coordss'): node.buffer_size = len(node.buffer_coordss)
    else: node.buffer_size = 0

# %%
from operator import attrgetter,methodcaller
for node in node_list:
    if hasattr(node,'buffer_coordss') is not None: print(node)
# Out:
# OctNode(6111115147):1 points - 4 fields
# OctNode(5222226357):1 points - 4 fields
# OctNode(5222226256):1 points - 4 fields
# OctNode(5222226255):1 points - 4 fields
# OctNode(4333337355):1 points - 4 fields
# OctNode(522223667):1 points - 4 fields
# OctNode(3253):1 points - 4 fields
# OctNode(3013):1 points - 4 fields
# OctNode(1071):1 points - 4 fields
# OctNode(5222226377):2 points - 4 fields
# OctNode(5222226355):2 points - 4 fields
# OctNode(5222226257):2 points - 4 fields
# OctNode(5222226254):2 points - 4 fields
# OctNode(433330373):2 points - 4 fields
# OctNode(6256):2 points - 4 fields
# OctNode(7000006147):3 points - 4 fields
# OctNode(7000004277):3 points - 4 fields
# OctNode(5222226374):3 points - 4 fields
# OctNode(5222226356):3 points - 4 fields
# OctNode(43333231):3 points - 4 fields
# OctNode(43333122):3 points - 4 fields
# OctNode(2402):3 points - 4 fields
# OctNode(236):3 points - 4 fields
# OctNode(7000006144):4 points - 4 fields
# OctNode(7000004275):4 points - 4 fields
# OctNode(5222226376):4 points - 4 fields
# OctNode(5222226354):4 points - 4 fields
# OctNode(4333337354):4 points - 4 fields
# OctNode(61111013):4 points - 4 fields
# OctNode(52222013):4 points - 4 fields
# OctNode(43333232):4 points - 4 fields
# OctNode(321):4 points - 4 fields
# OctNode(6111115145):5 points - 4 fields
# OctNode(433332737):5 points - 4 fields
# OctNode(52222165):5 points - 4 fields
# OctNode(43333274):5 points - 4 fields
# OctNode(3573):5 points - 4 fields
# OctNode(263):5 points - 4 fields
# OctNode(7000006146):6 points - 4 fields
# OctNode(61111010):6 points - 4 fields
# OctNode(43333123):6 points - 4 fields
# OctNode(230):6 points - 4 fields
# OctNode(7000006145):7 points - 4 fields
# OctNode(6111115146):7 points - 4 fields
# OctNode(522223666):7 points - 4 fields
# OctNode(522223621):7 points - 4 fields
# OctNode(43333254):7 points - 4 fields
# OctNode(43333233):7 points - 4 fields
# OctNode(43333230):7 points - 4 fields
# OctNode(43333210):7 points - 4 fields
# OctNode(3011):7 points - 4 fields
# OctNode(317):7 points - 4 fields
# OctNode(312):7 points - 4 fields
# OctNode(130):7 points - 4 fields
# OctNode(041):7 points - 4 fields
# OctNode(024):7 points - 4 fields
# OctNode(5222226375):8 points - 4 fields
# OctNode(522222620):8 points - 4 fields
# OctNode(522222533):8 points - 4 fields
# OctNode(61111144):8 points - 4 fields
# OctNode(43333020):8 points - 4 fields
# OctNode(43331334):8 points - 4 fields
# OctNode(7137):8 points - 4 fields
# OctNode(203):8 points - 4 fields
# OctNode(021):8 points - 4 fields
# OctNode(014):8 points - 4 fields
# OctNode(7527):9 points - 4 fields
# OctNode(2400):9 points - 4 fields
# OctNode(1751):9 points - 4 fields
# OctNode(327):9 points - 4 fields
# OctNode(042):9 points - 4 fields
# OctNode(522222603):10 points - 4 fields
# OctNode(433333624):10 points - 4 fields
# OctNode(43333074):10 points - 4 fields
# OctNode(674):10 points - 4 fields
# OctNode(260):10 points - 4 fields
# OctNode(206):10 points - 4 fields
# OctNode(012):10 points - 4 fields
# OctNode(4333337356):11 points - 4 fields
# OctNode(611111722):11 points - 4 fields
# OctNode(522222602):11 points - 4 fields
# OctNode(43333256):11 points - 4 fields
# OctNode(5315):11 points - 4 fields
# OctNode(372):11 points - 4 fields
# OctNode(522222601):12 points - 4 fields
# OctNode(61111054):12 points - 4 fields
# OctNode(43333213):12 points - 4 fields
# OctNode(43333211):12 points - 4 fields
# OctNode(43333076):12 points - 4 fields
# OctNode(5705):12 points - 4 fields
# OctNode(371):12 points - 4 fields
# OctNode(153):12 points - 4 fields
# OctNode(135):12 points - 4 fields
# OctNode(103):12 points - 4 fields
# OctNode(5222236041):13 points - 4 fields
# OctNode(611111406):13 points - 4 fields
# OctNode(522223603):13 points - 4 fields
# OctNode(433333626):13 points - 4 fields
# OctNode(433330372):13 points - 4 fields
# OctNode(43333212):13 points - 4 fields
# OctNode(642):13 points - 4 fields
# OctNode(5222227353):14 points - 4 fields
# OctNode(611111716):14 points - 4 fields
# OctNode(522223664):14 points - 4 fields
# OctNode(522222622):14 points - 4 fields
# OctNode(522222531):14 points - 4 fields
# OctNode(433333606):14 points - 4 fields
# OctNode(433332736):14 points - 4 fields
# OctNode(61111356):14 points - 4 fields
# OctNode(6546):14 points - 4 fields
# OctNode(5311):14 points - 4 fields
# OctNode(4524):14 points - 4 fields
# OctNode(406):14 points - 4 fields
# OctNode(7000005154):15 points - 4 fields
# OctNode(5222236040):15 points - 4 fields
# OctNode(522221622):15 points - 4 fields
# OctNode(52222012):15 points - 4 fields
# OctNode(52222010):15 points - 4 fields
# OctNode(4104):15 points - 4 fields
# OctNode(763):15 points - 4 fields
# OctNode(735):15 points - 4 fields
# OctNode(5222236263):16 points - 4 fields
# OctNode(700000503):16 points - 4 fields
# OctNode(61111056):16 points - 4 fields
# OctNode(52222164):16 points - 4 fields
# OctNode(43333276):16 points - 4 fields
# OctNode(4154):16 points - 4 fields
# OctNode(736):16 points - 4 fields
# OctNode(514):16 points - 4 fields
# OctNode(522223623):17 points - 4 fields
# OctNode(61111011):17 points - 4 fields
# OctNode(52222264):17 points - 4 fields
# OctNode(52222011):17 points - 4 fields
# OctNode(43331330):17 points - 4 fields
# OctNode(4333135):17 points - 4 fields
# OctNode(5375):17 points - 4 fields
# OctNode(624):17 points - 4 fields
# OctNode(700000510):18 points - 4 fields
# OctNode(522222505):18 points - 4 fields
# OctNode(70000073):18 points - 4 fields
# OctNode(5222233):18 points - 4 fields
# OctNode(3577):18 points - 4 fields
# OctNode(627):18 points - 4 fields
# OctNode(5222226373):19 points - 4 fields
# OctNode(522220505):19 points - 4 fields
# OctNode(70000044):19 points - 4 fields
# OctNode(61111055):19 points - 4 fields
# OctNode(61111012):19 points - 4 fields
# OctNode(52222055):19 points - 4 fields
# OctNode(4333134):19 points - 4 fields
# OctNode(1755):19 points - 4 fields
# OctNode(611111404):20 points - 4 fields
# OctNode(522222711):20 points - 4 fields
# OctNode(522222623):20 points - 4 fields
# OctNode(522220507):20 points - 4 fields
# OctNode(522220504):20 points - 4 fields
# OctNode(61111163):20 points - 4 fields
# OctNode(52222003):20 points - 4 fields
# OctNode(43333032):20 points - 4 fields
# OctNode(7000011):20 points - 4 fields
# OctNode(5222024):20 points - 4 fields
# OctNode(4333130):20 points - 4 fields
# OctNode(2070):20 points - 4 fields
# OctNode(6111115144):21 points - 4 fields
# OctNode(522223601):21 points - 4 fields
# OctNode(43333364):21 points - 4 fields
# OctNode(7133):21 points - 4 fields
# OctNode(672):21 points - 4 fields
# OctNode(5222236043):22 points - 4 fields
# OctNode(522223423):22 points - 4 fields
# OctNode(70000065):22 points - 4 fields
# OctNode(52222266):22 points - 4 fields
# OctNode(52222046):22 points - 4 fields
# OctNode(43333366):22 points - 4 fields
# OctNode(43333022):22 points - 4 fields
# OctNode(5222231):22 points - 4 fields
# OctNode(5645):22 points - 4 fields
# OctNode(3252):22 points - 4 fields
# OctNode(541):22 points - 4 fields
# OctNode(150):22 points - 4 fields
# OctNode(7000004356):23 points - 4 fields
# OctNode(433333713):23 points - 4 fields
# OctNode(433330371):23 points - 4 fields
# OctNode(43333377):23 points - 4 fields
# OctNode(43333277):23 points - 4 fields
# OctNode(43333033):23 points - 4 fields
# OctNode(7000013):23 points - 4 fields
# OctNode(5222215):23 points - 4 fields
# OctNode(753):23 points - 4 fields
# OctNode(522223422):24 points - 4 fields
# OctNode(522223420):24 points - 4 fields
# OctNode(52222267):24 points - 4 fields
# OctNode(52222064):24 points - 4 fields
# OctNode(52222047):24 points - 4 fields
# OctNode(4333131):24 points - 4 fields
# OctNode(7000005150):25 points - 4 fields
# OctNode(52222057):25 points - 4 fields
# OctNode(43333275):25 points - 4 fields
# OctNode(43333147):25 points - 4 fields
# OctNode(5222020):25 points - 4 fields
# OctNode(647):25 points - 4 fields
# OctNode(105):25 points - 4 fields
# OctNode(43333146):26 points - 4 fields
# OctNode(43333113):26 points - 4 fields
# OctNode(56737):26 points - 4 fields
# OctNode(4764):26 points - 4 fields
# OctNode(7000005256):27 points - 4 fields
# OctNode(522221623):27 points - 4 fields
# OctNode(522220730):27 points - 4 fields
# OctNode(522220525):27 points - 4 fields
# OctNode(61111357):27 points - 4 fields
# OctNode(52222001):27 points - 4 fields
# OctNode(5222211):27 points - 4 fields
# OctNode(4766):27 points - 4 fields
# OctNode(765):27 points - 4 fields
# OctNode(460):27 points - 4 fields
# OctNode(700000512):28 points - 4 fields
# OctNode(522221620):28 points - 4 fields
# OctNode(433333733):28 points - 4 fields
# OctNode(61111017):28 points - 4 fields
# OctNode(567327):28 points - 4 fields
# OctNode(7000004274):29 points - 4 fields
# OctNode(700000613):29 points - 4 fields
# OctNode(7000017):29 points - 4 fields
# OctNode(5675):29 points - 4 fields
# OctNode(4754):29 points - 4 fields
# OctNode(433333731):30 points - 4 fields
# OctNode(43331335):30 points - 4 fields
# OctNode(43331331):30 points - 4 fields
# OctNode(6111132):30 points - 4 fields
# OctNode(5644):30 points - 4 fields
# OctNode(700000501):31 points - 4 fields
# OctNode(611111424):31 points - 4 fields
# OctNode(522222501):31 points - 4 fields
# OctNode(52222166):31 points - 4 fields
# OctNode(52222065):31 points - 4 fields
# OctNode(611111436):32 points - 4 fields
# OctNode(433332735):32 points - 4 fields
# OctNode(43333375):32 points - 4 fields
# OctNode(7000012):32 points - 4 fields
# OctNode(4755):32 points - 4 fields
# OctNode(4155):32 points - 4 fields
# OctNode(43333164):33 points - 4 fields
# OctNode(6111133):33 points - 4 fields
# OctNode(2352):33 points - 4 fields
# OctNode(450):33 points - 4 fields
# OctNode(700000402):34 points - 4 fields
# OctNode(611111415):34 points - 4 fields
# OctNode(611111407):34 points - 4 fields
# OctNode(3012):34 points - 4 fields
# OctNode(611111512):35 points - 4 fields
# OctNode(52222245):35 points - 4 fields
# OctNode(7000010):35 points - 4 fields
# OctNode(56735):35 points - 4 fields
# OctNode(5377):35 points - 4 fields
# OctNode(611111426):36 points - 4 fields
# OctNode(433333401):36 points - 4 fields
# OctNode(52222276):36 points - 4 fields
# OctNode(43333024):36 points - 4 fields
# OctNode(517):36 points - 4 fields
# OctNode(700000513):37 points - 4 fields
# OctNode(611111411):37 points - 4 fields
# OctNode(61111146):37 points - 4 fields
# OctNode(43333255):37 points - 4 fields
# OctNode(6111136):37 points - 4 fields
# OctNode(7000004276):38 points - 4 fields
# OctNode(522222421):38 points - 4 fields
# OctNode(52222244):38 points - 4 fields
# OctNode(52222002):38 points - 4 fields
# OctNode(43333154):38 points - 4 fields
# OctNode(1070):38 points - 4 fields
# OctNode(522222632):39 points - 4 fields
# OctNode(43333142):39 points - 4 fields
# OctNode(405):39 points - 4 fields
# OctNode(611111707):40 points - 4 fields
# OctNode(611111425):40 points - 4 fields
# OctNode(522222600):40 points - 4 fields
# OctNode(433333607):40 points - 4 fields
# OctNode(52222167):40 points - 4 fields
# OctNode(6252):40 points - 4 fields
# OctNode(700000502):41 points - 4 fields
# OctNode(522222723):41 points - 4 fields
# OctNode(522222425):41 points - 4 fields
# OctNode(4100):41 points - 4 fields
# OctNode(3243):41 points - 4 fields
# OctNode(574):41 points - 4 fields
# OctNode(611111417):42 points - 4 fields
# OctNode(433333406):42 points - 4 fields
# OctNode(700000411):43 points - 4 fields
# OctNode(522220501):43 points - 4 fields
# OctNode(433333531):43 points - 4 fields
# OctNode(70000045):43 points - 4 fields
# OctNode(61111057):43 points - 4 fields
# OctNode(5222213):43 points - 4 fields
# OctNode(3242):43 points - 4 fields
# OctNode(611111726):44 points - 4 fields
# OctNode(522223421):44 points - 4 fields
# OctNode(522222732):44 points - 4 fields
# OctNode(52222045):44 points - 4 fields
# OctNode(43333376):44 points - 4 fields
# OctNode(5222021):44 points - 4 fields
# OctNode(522222615):45 points - 4 fields
# OctNode(52222161):45 points - 4 fields
# OctNode(43333165):45 points - 4 fields
# OctNode(4333304):45 points - 4 fields
# OctNode(7525):45 points - 4 fields
# OctNode(700000400):46 points - 4 fields
# OctNode(43333145):46 points - 4 fields
# OctNode(43333075):46 points - 4 fields
# OctNode(567326):46 points - 4 fields
# OctNode(567323):46 points - 4 fields
# OctNode(3143):46 points - 4 fields
# OctNode(2353):46 points - 4 fields
# OctNode(571):46 points - 4 fields
# OctNode(7000004357):47 points - 4 fields
# OctNode(700000511):47 points - 4 fields
# OctNode(611111720):47 points - 4 fields
# OctNode(522223600):47 points - 4 fields
# OctNode(522220621):47 points - 4 fields
# OctNode(433333722):47 points - 4 fields
# OctNode(43333374):47 points - 4 fields
# OctNode(56734):47 points - 4 fields
# OctNode(56731):47 points - 4 fields
# OctNode(522222715):48 points - 4 fields
# OctNode(70000143):48 points - 4 fields
# OctNode(52222247):48 points - 4 fields
# OctNode(611111734):49 points - 4 fields
# OctNode(611111705):49 points - 4 fields
# OctNode(522222513):49 points - 4 fields
# OctNode(522222422):49 points - 4 fields
# OctNode(433333604):49 points - 4 fields
# OctNode(43333156):49 points - 4 fields
# OctNode(7000004271):50 points - 4 fields
# OctNode(522222423):50 points - 4 fields
# OctNode(756):50 points - 4 fields
# OctNode(700000507):51 points - 4 fields
# OctNode(522222621):51 points - 4 fields
# OctNode(433333405):51 points - 4 fields
# OctNode(433333404):51 points - 4 fields
# OctNode(52222365):51 points - 4 fields
# OctNode(52222274):51 points - 4 fields
# OctNode(6111137):51 points - 4 fields
# OctNode(7135):51 points - 4 fields
# OctNode(3571):51 points - 4 fields
# OctNode(2406):51 points - 4 fields
# OctNode(231):51 points - 4 fields
# OctNode(522222413):52 points - 4 fields
# OctNode(433333632):52 points - 4 fields
# OctNode(43333175):52 points - 4 fields
# OctNode(43333157):52 points - 4 fields
# OctNode(43333023):52 points - 4 fields
# OctNode(6544):52 points - 4 fields
# OctNode(6254):52 points - 4 fields
# OctNode(0470):52 points - 4 fields
# OctNode(5222236063):53 points - 4 fields
# OctNode(700000500):53 points - 4 fields
# OctNode(522222630):53 points - 4 fields
# OctNode(522222613):53 points - 4 fields
# OctNode(522220632):53 points - 4 fields
# OctNode(52222054):53 points - 4 fields
# OctNode(7446):53 points - 4 fields
# OctNode(3707):53 points - 4 fields
# OctNode(3003):53 points - 4 fields
# OctNode(5222236262):54 points - 4 fields
# OctNode(5222236261):54 points - 4 fields
# OctNode(522222612):54 points - 4 fields
# OctNode(433333430):54 points - 4 fields
# OctNode(433331735):54 points - 4 fields
# OctNode(5317):54 points - 4 fields
# OctNode(1561):54 points - 4 fields
# OctNode(522220506):55 points - 4 fields
# OctNode(433331731):55 points - 4 fields
# OctNode(70000064):55 points - 4 fields
# OctNode(70000046):55 points - 4 fields
# OctNode(2652):55 points - 4 fields
# OctNode(1073):55 points - 4 fields
# OctNode(522222610):56 points - 4 fields
# OctNode(61111155):56 points - 4 fields
# OctNode(52222265):56 points - 4 fields
# OctNode(7607):56 points - 4 fields
# OctNode(7457):56 points - 4 fields
# OctNode(5677):56 points - 4 fields
# OctNode(1061):56 points - 4 fields
# OctNode(547):56 points - 4 fields
# OctNode(7000004355):57 points - 4 fields
# OctNode(5222236042):57 points - 4 fields
# OctNode(700000603):57 points - 4 fields
# OctNode(611111712):57 points - 4 fields
# OctNode(522220732):57 points - 4 fields
# OctNode(56730):57 points - 4 fields
# OctNode(43333144):58 points - 4 fields
# OctNode(3701):58 points - 4 fields
# OctNode(2772):58 points - 4 fields
# OctNode(456):58 points - 4 fields
# OctNode(6111115142):59 points - 4 fields
# OctNode(611111724):59 points - 4 fields
# OctNode(611111704):59 points - 4 fields
# OctNode(522222611):59 points - 4 fields
# OctNode(70000047):59 points - 4 fields
# OctNode(43333357):59 points - 4 fields
# OctNode(267):59 points - 4 fields
# OctNode(7000005254):60 points - 4 fields
# OctNode(700000432):60 points - 4 fields
# OctNode(522222510):60 points - 4 fields
# OctNode(6547):60 points - 4 fields
# OctNode(5313):60 points - 4 fields
# OctNode(1753):60 points - 4 fields
# OctNode(522222431):61 points - 4 fields
# OctNode(52222056):61 points - 4 fields
# OctNode(43333356):61 points - 4 fields
# OctNode(4333326):61 points - 4 fields
# OctNode(4224):61 points - 4 fields
# OctNode(1221):61 points - 4 fields
# OctNode(700000523):62 points - 4 fields
# OctNode(522220635):62 points - 4 fields
# OctNode(61111147):62 points - 4 fields
# OctNode(52222077):62 points - 4 fields
# OctNode(43333155):62 points - 4 fields
# OctNode(0330):62 points - 4 fields
# OctNode(522223622):63 points - 4 fields
# OctNode(522222512):63 points - 4 fields
# OctNode(522222503):63 points - 4 fields
# OctNode(567325):63 points - 4 fields
# OctNode(522223403):64 points - 4 fields
# OctNode(433333417):64 points - 4 fields
# OctNode(61111145):64 points - 4 fields
# OctNode(52222000):64 points - 4 fields
# OctNode(43333121):64 points - 4 fields
# OctNode(567322):64 points - 4 fields
# OctNode(1361):64 points - 4 fields
# OctNode(326):64 points - 4 fields
# OctNode(045):64 points - 4 fields
# OctNode(5222236060):65 points - 4 fields
# OctNode(522223402):65 points - 4 fields
# OctNode(52222347):65 points - 4 fields
# OctNode(43333257):65 points - 4 fields
# OctNode(7307):65 points - 4 fields
# OctNode(5125):65 points - 4 fields
# OctNode(237):65 points - 4 fields
# OctNode(433332534):66 points - 4 fields
# OctNode(43333026):66 points - 4 fields
# OctNode(7000015):66 points - 4 fields
# OctNode(567324):66 points - 4 fields
# OctNode(4034):66 points - 4 fields
# OctNode(7000004354):67 points - 4 fields
# OctNode(61111354):67 points - 4 fields
# OctNode(52222246):67 points - 4 fields
# OctNode(52222066):67 points - 4 fields
# OctNode(43333365):67 points - 4 fields
# OctNode(7606):67 points - 4 fields
# OctNode(6337):67 points - 4 fields
# OctNode(4756):67 points - 4 fields
# OctNode(2656):67 points - 4 fields
# OctNode(0170):67 points - 4 fields
# OctNode(611111500):68 points - 4 fields
# OctNode(433333631):68 points - 4 fields
# OctNode(433333434):68 points - 4 fields
# OctNode(433330377):68 points - 4 fields
# OctNode(6416):68 points - 4 fields
# OctNode(611111511):69 points - 4 fields
# OctNode(522222532):69 points - 4 fields
# OctNode(522222530):69 points - 4 fields
# OctNode(522220611):69 points - 4 fields
# OctNode(5222220):69 points - 4 fields
# OctNode(5373):69 points - 4 fields
# OctNode(4220):69 points - 4 fields
# OctNode(2773):69 points - 4 fields
# OctNode(2052):69 points - 4 fields
# OctNode(015):69 points - 4 fields
# OctNode(522220623):70 points - 4 fields
# OctNode(70000142):70 points - 4 fields
# OctNode(5371):70 points - 4 fields
# OctNode(4765):70 points - 4 fields
# OctNode(611111737):71 points - 4 fields
# OctNode(611111526):71 points - 4 fields
# OctNode(522220733):71 points - 4 fields
# OctNode(43333345):71 points - 4 fields
# OctNode(5222025):71 points - 4 fields
# OctNode(5707):71 points - 4 fields
# OctNode(3002):71 points - 4 fields
# OctNode(4767):72 points - 4 fields
# OctNode(4525):72 points - 4 fields
# OctNode(3141):72 points - 4 fields
# OctNode(0171):72 points - 4 fields
# OctNode(522223407):73 points - 4 fields
# OctNode(522220522):73 points - 4 fields
# OctNode(433333500):73 points - 4 fields
# OctNode(433332732):73 points - 4 fields
# OctNode(43333111):73 points - 4 fields
# OctNode(4030):73 points - 4 fields
# OctNode(1363):73 points - 4 fields
# OctNode(700000401):74 points - 4 fields
# OctNode(61111355):74 points - 4 fields
# OctNode(7447):74 points - 4 fields
# OctNode(522222410):75 points - 4 fields
# OctNode(43333116):75 points - 4 fields
# OctNode(43333112):75 points - 4 fields
# OctNode(7223):75 points - 4 fields
# OctNode(6336):75 points - 4 fields
# OctNode(1441):75 points - 4 fields
# OctNode(522223425):76 points - 4 fields
# OctNode(522222733):76 points - 4 fields
# OctNode(433331734):76 points - 4 fields
# OctNode(70000141):76 points - 4 fields
# OctNode(43333344):76 points - 4 fields
# OctNode(5222236260):77 points - 4 fields
# OctNode(43331333):77 points - 4 fields
# OctNode(6111106):77 points - 4 fields
# OctNode(5222230):77 points - 4 fields
# OctNode(4333300):77 points - 4 fields
# OctNode(2076):77 points - 4 fields
# OctNode(310):77 points - 4 fields
# OctNode(046):77 points - 4 fields
# OctNode(611111432):78 points - 4 fields
# OctNode(43333120):78 points - 4 fields
# OctNode(7603):78 points - 4 fields
# OctNode(7131):78 points - 4 fields
# OctNode(3010):78 points - 4 fields
# OctNode(0660):78 points - 4 fields
# OctNode(700000412):79 points - 4 fields
# OctNode(522223400):79 points - 4 fields
# OctNode(70000071):79 points - 4 fields
# OctNode(61111353):79 points - 4 fields
# OctNode(43333070):79 points - 4 fields
# OctNode(5222232):79 points - 4 fields
# OctNode(34164):79 points - 4 fields
# OctNode(2073):79 points - 4 fields
# OctNode(1223):79 points - 4 fields
# OctNode(0474):79 points - 4 fields
# OctNode(43333166):80 points - 4 fields
# OctNode(43331332):80 points - 4 fields
# OctNode(70447):80 points - 4 fields
# OctNode(5425):80 points - 4 fields
# OctNode(3575):80 points - 4 fields
# OctNode(3001):80 points - 4 fields
# OctNode(2404):80 points - 4 fields
# OctNode(1075):80 points - 4 fields
# OctNode(762):80 points - 4 fields
# OctNode(522222633):81 points - 4 fields
# OctNode(7000001):81 points - 4 fields
# OctNode(344441):81 points - 4 fields
# OctNode(7000005255):82 points - 4 fields
# OctNode(522222537):82 points - 4 fields
# OctNode(522220526):82 points - 4 fields
# OctNode(43333367):82 points - 4 fields
# OctNode(43333354):82 points - 4 fields
# OctNode(4226):82 points - 4 fields
# OctNode(70000054):83 points - 4 fields
# OctNode(34057):83 points - 4 fields
# OctNode(102):83 points - 4 fields
# OctNode(6557):84 points - 4 fields
# OctNode(1565):84 points - 4 fields
# OctNode(0270):84 points - 4 fields
# OctNode(5222227352):85 points - 4 fields
# OctNode(700000403):85 points - 4 fields
# OctNode(611111400):85 points - 4 fields
# OctNode(522223663):85 points - 4 fields
# OctNode(433333504):85 points - 4 fields
# OctNode(465):85 points - 4 fields
# OctNode(522223627):86 points - 4 fields
# OctNode(6716):86 points - 4 fields
# OctNode(522221621):87 points - 4 fields
# OctNode(433333712):87 points - 4 fields
# OctNode(433330376):87 points - 4 fields
# OctNode(6111102):87 points - 4 fields
# OctNode(7226):87 points - 4 fields
# OctNode(3743):87 points - 4 fields
# OctNode(2113):87 points - 4 fields
# OctNode(0664):87 points - 4 fields
# OctNode(11):87 points - 4 fields
# OctNode(00):87 points - 4 fields
# OctNode(522222720):88 points - 4 fields
# OctNode(522220731):88 points - 4 fields
# OctNode(433331730):88 points - 4 fields
# OctNode(433314):88 points - 4 fields
# OctNode(2777):88 points - 4 fields
# OctNode(732):88 points - 4 fields
# OctNode(700000415):89 points - 4 fields
# OctNode(611111522):89 points - 4 fields
# OctNode(611111402):89 points - 4 fields
# OctNode(522223602):89 points - 4 fields
# OctNode(522220625):89 points - 4 fields
# OctNode(522220527):89 points - 4 fields
# OctNode(43333250):89 points - 4 fields
# OctNode(433315):89 points - 4 fields
# OctNode(61346):89 points - 4 fields
# OctNode(7222):89 points - 4 fields
# OctNode(1060):89 points - 4 fields
# OctNode(700000430):90 points - 4 fields
# OctNode(700000413):90 points - 4 fields
# OctNode(433333605):90 points - 4 fields
# OctNode(7117):90 points - 4 fields
# OctNode(5121):90 points - 4 fields
# OctNode(700000612):91 points - 4 fields
# OctNode(700000611):91 points - 4 fields
# OctNode(34627):91 points - 4 fields
# OctNode(522222511):92 points - 4 fields
# OctNode(52222254):92 points - 4 fields
# OctNode(43333030):92 points - 4 fields
# OctNode(7000002):92 points - 4 fields
# OctNode(34513):92 points - 4 fields
# OctNode(5335):92 points - 4 fields
# OctNode(4534):92 points - 4 fields
# OctNode(764):92 points - 4 fields
# OctNode(315):92 points - 4 fields
# OctNode(611111706):93 points - 4 fields
# OctNode(611111533):93 points - 4 fields
# OctNode(61111166):93 points - 4 fields
# OctNode(43333167):93 points - 4 fields
# OctNode(6333):93 points - 4 fields
# OctNode(4535):93 points - 4 fields
# OctNode(402):93 points - 4 fields
# OctNode(611111434):94 points - 4 fields
# OctNode(522222432):94 points - 4 fields
# OctNode(433330352):94 points - 4 fields
# OctNode(5222217):94 points - 4 fields
# OctNode(16073):94 points - 4 fields
# OctNode(5674):94 points - 4 fields
# OctNode(4151):94 points - 4 fields
# OctNode(5222237):95 points - 4 fields
# OctNode(5222222):95 points - 4 fields
# OctNode(70507):95 points - 4 fields
# OctNode(70173):95 points - 4 fields
# OctNode(2446):95 points - 4 fields
# OctNode(1440):95 points - 4 fields
# OctNode(5222236061):96 points - 4 fields
# OctNode(43333077):96 points - 4 fields
# OctNode(4333333):96 points - 4 fields
# OctNode(6257):96 points - 4 fields
# OctNode(2112):96 points - 4 fields
# OctNode(201):96 points - 4 fields
# OctNode(5222227356):97 points - 4 fields
# OctNode(433333703):97 points - 4 fields
# OctNode(43333021):97 points - 4 fields
# OctNode(34573):97 points - 4 fields
# OctNode(34243):97 points - 4 fields
# OctNode(7523):97 points - 4 fields
# OctNode(66):97 points - 4 fields
# OctNode(700000421):98 points - 4 fields
# OctNode(700000410):98 points - 4 fields
# OctNode(611111530):98 points - 4 fields
# OctNode(611111410):98 points - 4 fields
# OctNode(52222074):98 points - 4 fields
# OctNode(52222044):98 points - 4 fields
# OctNode(7000003):98 points - 4 fields
# OctNode(70446):98 points - 4 fields
# OctNode(52315):98 points - 4 fields
# OctNode(7526):98 points - 4 fields
# OctNode(522222710):99 points - 4 fields
# OctNode(522222504):99 points - 4 fields
# OctNode(433333633):99 points - 4 fields
# OctNode(700023):99 points - 4 fields
# OctNode(61332):99 points - 4 fields
# OctNode(61000):99 points - 4 fields
# OctNode(16751):99 points - 4 fields
# OctNode(7227):99 points - 4 fields
# OctNode(5647):99 points - 4 fields
# OctNode(2442):99 points - 4 fields
# OctNode(1771):99 points - 4 fields
# OctNode(0471):99 points - 4 fields
# OctNode(675):99 points - 4 fields
# OctNode(376):99 points - 4 fields
# OctNode(611111736):100 points - 4 fields
# OctNode(433333710):100 points - 4 fields
# OctNode(52222006):100 points - 4 fields
# OctNode(077762):100 points - 4 fields
# OctNode(61344):100 points - 4 fields
# OctNode(43706):100 points - 4 fields
# OctNode(6414):100 points - 4 fields
# OctNode(5005):100 points - 4 fields
# OctNode(2776):100 points - 4 fields
# OctNode(1757):100 points - 4 fields
# OctNode(104):100 points - 4 fields
# OctNode(522220606):101 points - 4 fields
# OctNode(433332734):101 points - 4 fields
# OctNode(61111164):101 points - 4 fields
# OctNode(700017):101 points - 4 fields
# OctNode(43704):101 points - 4 fields
# OctNode(43111):101 points - 4 fields
# OctNode(6717):101 points - 4 fields
# OctNode(6216):101 points - 4 fields
# OctNode(5424):101 points - 4 fields
# OctNode(4757):101 points - 4 fields
# OctNode(3553):101 points - 4 fields
# OctNode(3251):101 points - 4 fields
# OctNode(023):101 points - 4 fields
# OctNode(433333511):102 points - 4 fields
# OctNode(52222256):102 points - 4 fields
# OctNode(5222235):102 points - 4 fields
# OctNode(522275):102 points - 4 fields
# OctNode(52317):102 points - 4 fields
# OctNode(3702):102 points - 4 fields
# OctNode(7000005151):103 points - 4 fields
# OctNode(700000602):103 points - 4 fields
# OctNode(70000145):103 points - 4 fields
# OctNode(52222067):103 points - 4 fields
# OctNode(43333174):103 points - 4 fields
# OctNode(52311):103 points - 4 fields
# OctNode(25112):103 points - 4 fields
# OctNode(07312):103 points - 4 fields
# OctNode(4774):103 points - 4 fields
# OctNode(1445):103 points - 4 fields
# OctNode(5222236046):104 points - 4 fields
# OctNode(611111701):104 points - 4 fields
# OctNode(522220624):104 points - 4 fields
# OctNode(433333622):104 points - 4 fields
# OctNode(433333532):104 points - 4 fields
# OctNode(433332733):104 points - 4 fields
# OctNode(433330355):104 points - 4 fields
# OctNode(52222007):104 points - 4 fields
# OctNode(700022):104 points - 4 fields
# OctNode(522205):104 points - 4 fields
# OctNode(0560):104 points - 4 fields
# OctNode(5222227357):105 points - 4 fields
# OctNode(611111405):105 points - 4 fields
# OctNode(433330353):105 points - 4 fields
# OctNode(43333347):105 points - 4 fields
# OctNode(61415):105 points - 4 fields
# OctNode(25706):105 points - 4 fields
# OctNode(6212):105 points - 4 fields
# OctNode(013):105 points - 4 fields
# OctNode(7000005250):106 points - 4 fields
# OctNode(433333501):106 points - 4 fields
# OctNode(7000000):106 points - 4 fields
# OctNode(61416):106 points - 4 fields
# OctNode(61006):106 points - 4 fields
# OctNode(43705):106 points - 4 fields
# OctNode(34511):106 points - 4 fields
# OctNode(34075):106 points - 4 fields
# OctNode(34053):106 points - 4 fields
# OctNode(7303):106 points - 4 fields
# OctNode(0524):106 points - 4 fields
# OctNode(137):106 points - 4 fields
# OctNode(52375):107 points - 4 fields
# OctNode(43214):107 points - 4 fields
# OctNode(43115):107 points - 4 fields
# OctNode(34160):107 points - 4 fields
# OctNode(16755):107 points - 4 fields
# OctNode(07333):107 points - 4 fields
# OctNode(6332):107 points - 4 fields
# OctNode(5000):107 points - 4 fields
# OctNode(5222227354):108 points - 4 fields
# OctNode(611111501):108 points - 4 fields
# OctNode(43333110):108 points - 4 fields
# OctNode(344443):108 points - 4 fields
# OctNode(077760):108 points - 4 fields
# OctNode(43110):108 points - 4 fields
# OctNode(34623):108 points - 4 fields
# OctNode(7257):108 points - 4 fields
# OctNode(0662):108 points - 4 fields
# OctNode(0475):108 points - 4 fields
# OctNode(673):108 points - 4 fields
# OctNode(522222631):109 points - 4 fields
# OctNode(522220605):109 points - 4 fields
# OctNode(433333627):109 points - 4 fields
# OctNode(700013):109 points - 4 fields
# OctNode(34626):109 points - 4 fields
# OctNode(34055):109 points - 4 fields
# OctNode(25111):109 points - 4 fields
# OctNode(07610):109 points - 4 fields
# OctNode(433333711):110 points - 4 fields
# OctNode(522204):110 points - 4 fields
# OctNode(433316):110 points - 4 fields
# OctNode(16071):110 points - 4 fields
# OctNode(7000006142):111 points - 4 fields
# OctNode(5222236267):111 points - 4 fields
# OctNode(433333702):111 points - 4 fields
# OctNode(52222255):111 points - 4 fields
# OctNode(5222212):111 points - 4 fields
# OctNode(522264):111 points - 4 fields
# OctNode(70217):111 points - 4 fields
# OctNode(61336):111 points - 4 fields
# OctNode(61333):111 points - 4 fields
# OctNode(61002):111 points - 4 fields
# OctNode(56733):111 points - 4 fields
# OctNode(52335):111 points - 4 fields
# OctNode(25343):111 points - 4 fields
# OctNode(16561):111 points - 4 fields
# OctNode(07510):111 points - 4 fields
# OctNode(07310):111 points - 4 fields
# OctNode(7507):111 points - 4 fields
# OctNode(5725):111 points - 4 fields
# OctNode(5001):111 points - 4 fields
# OctNode(3000):111 points - 4 fields
# OctNode(320):111 points - 4 fields
# OctNode(433333614):112 points - 4 fields
# OctNode(522277):112 points - 4 fields
# OctNode(70437):112 points - 4 fields
# OctNode(70163):112 points - 4 fields
# OctNode(61347):112 points - 4 fields
# OctNode(61077):112 points - 4 fields
# OctNode(43724):112 points - 4 fields
# OctNode(07272):112 points - 4 fields
# OctNode(07170):112 points - 4 fields
# OctNode(7256):112 points - 4 fields
# OctNode(7247):112 points - 4 fields
# OctNode(522220620):113 points - 4 fields
# OctNode(61111154):113 points - 4 fields
# OctNode(700047):113 points - 4 fields
# OctNode(166641):113 points - 4 fields
# OctNode(077754):113 points - 4 fields
# OctNode(077750):113 points - 4 fields
# OctNode(70436):113 points - 4 fields
# OctNode(70177):113 points - 4 fields
# OctNode(70172):113 points - 4 fields
# OctNode(61004):113 points - 4 fields
# OctNode(52614):113 points - 4 fields
# OctNode(52314):113 points - 4 fields
# OctNode(43114):113 points - 4 fields
# OctNode(34577):113 points - 4 fields
# OctNode(25704):113 points - 4 fields
# OctNode(16753):113 points - 4 fields
# OctNode(16440):113 points - 4 fields
# OctNode(7505):113 points - 4 fields
# OctNode(3257):113 points - 4 fields
# OctNode(611111711):114 points - 4 fields
# OctNode(70000147):114 points - 4 fields
# OctNode(611102):114 points - 4 fields
# OctNode(70123):114 points - 4 fields
# OctNode(52704):114 points - 4 fields
# OctNode(25054):114 points - 4 fields
# OctNode(16441):114 points - 4 fields
# OctNode(16070):114 points - 4 fields
# OctNode(1444):114 points - 4 fields
# OctNode(0520):114 points - 4 fields
# OctNode(510):114 points - 4 fields
# OctNode(154):114 points - 4 fields
# OctNode(700000514):115 points - 4 fields
# OctNode(611111513):115 points - 4 fields
# OctNode(522222420):115 points - 4 fields
# OctNode(52222257):115 points - 4 fields
# OctNode(433324):115 points - 4 fields
# OctNode(255552):115 points - 4 fields
# OctNode(25732):115 points - 4 fields
# OctNode(25072):115 points - 4 fields
# OctNode(25052):115 points - 4 fields
# OctNode(07614):115 points - 4 fields
# OctNode(07311):115 points - 4 fields
# OctNode(0332):115 points - 4 fields
# OctNode(0272):115 points - 4 fields
# OctNode(611111503):116 points - 4 fields
# OctNode(433310):116 points - 4 fields
# OctNode(61414):116 points - 4 fields
# OctNode(52425):116 points - 4 fields
# OctNode(43714):116 points - 4 fields
# OctNode(34653):116 points - 4 fields
# OctNode(25110):116 points - 4 fields
# OctNode(16445):116 points - 4 fields
# OctNode(5124):116 points - 4 fields
# OctNode(4111):116 points - 4 fields
# OctNode(700046):117 points - 4 fields
# OctNode(433311):117 points - 4 fields
# OctNode(70503):117 points - 4 fields
# OctNode(70426):117 points - 4 fields
# OctNode(70213):117 points - 4 fields
# OctNode(70166):117 points - 4 fields
# OctNode(52706):117 points - 4 fields
# OctNode(52371):117 points - 4 fields
# OctNode(52121):117 points - 4 fields
# OctNode(34520):117 points - 4 fields
# OctNode(5646):117 points - 4 fields
# OctNode(5075):117 points - 4 fields
# OctNode(3747):117 points - 4 fields
# OctNode(2050):117 points - 4 fields
# OctNode(5222236067):118 points - 4 fields
# OctNode(433333530):118 points - 4 fields
# OctNode(433333407):118 points - 4 fields
# OctNode(5222223):118 points - 4 fields
# OctNode(611136):118 points - 4 fields
# OctNode(52707):118 points - 4 fields
# OctNode(34571):118 points - 4 fields
# OctNode(07520):118 points - 4 fields
# OctNode(07332):118 points - 4 fields
# OctNode(07270):118 points - 4 fields
# OctNode(4101):118 points - 4 fields
# OctNode(77):118 points - 4 fields
# OctNode(433330370):119 points - 4 fields
# OctNode(700027):119 points - 4 fields
# OctNode(522201):119 points - 4 fields
# OctNode(61356):119 points - 4 fields
# OctNode(52075):119 points - 4 fields
# OctNode(43635):119 points - 4 fields
# OctNode(25730):119 points - 4 fields
# OctNode(07313):119 points - 4 fields
# OctNode(07273):119 points - 4 fields
# OctNode(7602):119 points - 4 fields
# OctNode(6556):119 points - 4 fields
# OctNode(4222):119 points - 4 fields
# OctNode(026):119 points - 4 fields
# OctNode(433333602):120 points - 4 fields
# OctNode(700045):120 points - 4 fields
# OctNode(700011):120 points - 4 fields
# OctNode(166640):120 points - 4 fields
# OctNode(70505):120 points - 4 fields
# OctNode(61036):120 points - 4 fields
# OctNode(52705):120 points - 4 fields
# OctNode(52125):120 points - 4 fields
# OctNode(34431):120 points - 4 fields
# OctNode(25735):120 points - 4 fields
# OctNode(25347):120 points - 4 fields
# OctNode(16273):120 points - 4 fields
# OctNode(16075):120 points - 4 fields
# OctNode(07511):120 points - 4 fields
# OctNode(07330):120 points - 4 fields
# OctNode(6555):120 points - 4 fields
# OctNode(204):120 points - 4 fields
# OctNode(522220523):121 points - 4 fields
# OctNode(433333620):121 points - 4 fields
# OctNode(077766):121 points - 4 fields
# OctNode(61537):121 points - 4 fields
# OctNode(52725):121 points - 4 fields
# OctNode(43707):121 points - 4 fields
# OctNode(34551):121 points - 4 fields
# OctNode(34163):121 points - 4 fields
# OctNode(25051):121 points - 4 fields
# OctNode(5004):121 points - 4 fields
# OctNode(0666):121 points - 4 fields
# OctNode(132):121 points - 4 fields
# OctNode(33):121 points - 4 fields
# OctNode(522222713):122 points - 4 fields
# OctNode(4333324):122 points - 4 fields
# OctNode(52345):122 points - 4 fields
# OctNode(43164):122 points - 4 fields
# OctNode(34617):122 points - 4 fields
# OctNode(25734):122 points - 4 fields
# OctNode(16366):122 points - 4 fields
# OctNode(07515):122 points - 4 fields
# OctNode(07271):122 points - 4 fields
# OctNode(0564):122 points - 4 fields
# OctNode(22):122 points - 4 fields
# OctNode(522222417):123 points - 4 fields
# OctNode(522220615):123 points - 4 fields
# OctNode(433333720):123 points - 4 fields
# OctNode(433331733):123 points - 4 fields
# OctNode(611132):123 points - 4 fields
# OctNode(522273):123 points - 4 fields
# OctNode(70127):123 points - 4 fields
# OctNode(61337):123 points - 4 fields
# OctNode(25115):123 points - 4 fields
# OctNode(7115):123 points - 4 fields
# OctNode(7113):123 points - 4 fields
# OctNode(7000004270):124 points - 4 fields
# OctNode(700015):124 points - 4 fields
# OctNode(077764):124 points - 4 fields
# OctNode(70433):124 points - 4 fields
# OctNode(61522):124 points - 4 fields
# OctNode(52426):124 points - 4 fields
# OctNode(43634):124 points - 4 fields
# OctNode(43630):124 points - 4 fields
# OctNode(34517):124 points - 4 fields
# OctNode(34413):124 points - 4 fields
# OctNode(25742):124 points - 4 fields
# OctNode(25113):124 points - 4 fields
# OctNode(25050):124 points - 4 fields
# OctNode(16565):124 points - 4 fields
# OctNode(16077):124 points - 4 fields
# OctNode(07514):124 points - 4 fields
# OctNode(4105):124 points - 4 fields
# OctNode(522276):125 points - 4 fields
# OctNode(522271):125 points - 4 fields
# OctNode(522200):125 points - 4 fields
# OctNode(255553):125 points - 4 fields
# OctNode(70435):125 points - 4 fields
# OctNode(61434):125 points - 4 fields
# OctNode(61034):125 points - 4 fields
# OctNode(34051):125 points - 4 fields
# OctNode(25436):125 points - 4 fields
# OctNode(25073):125 points - 4 fields
# OctNode(16361):125 points - 4 fields
# OctNode(07331):125 points - 4 fields
# OctNode(07171):125 points - 4 fields
# OctNode(2111):125 points - 4 fields
# OctNode(44):125 points - 4 fields
# OctNode(7000005257):126 points - 4 fields
# OctNode(611156):126 points - 4 fields
# OctNode(70444):126 points - 4 fields
# OctNode(52615):126 points - 4 fields
# OctNode(52377):126 points - 4 fields
# OctNode(25340):126 points - 4 fields
# OctNode(07650):126 points - 4 fields
# OctNode(623):126 points - 4 fields
# OctNode(522220613):127 points - 4 fields
# OctNode(25070):127 points - 4 fields
# OctNode(07551):127 points - 4 fields
# OctNode(4115):127 points - 4 fields
# OctNode(1220):127 points - 4 fields
# OctNode(611111427):128 points - 4 fields
# OctNode(522220500):128 points - 4 fields
# OctNode(52222363):128 points - 4 fields
# OctNode(433317):128 points - 4 fields
# OctNode(344440):128 points - 4 fields
# OctNode(70427):128 points - 4 fields
# OctNode(70212):128 points - 4 fields
# OctNode(70171):128 points - 4 fields
# OctNode(61072):128 points - 4 fields
# OctNode(34167):128 points - 4 fields
# OctNode(25702):128 points - 4 fields
# OctNode(25472):128 points - 4 fields
# OctNode(16754):128 points - 4 fields
# OctNode(16701):128 points - 4 fields
# OctNode(16360):128 points - 4 fields
# OctNode(07554):128 points - 4 fields
# OctNode(4031):128 points - 4 fields
# OctNode(1564):128 points - 4 fields
# OctNode(522222515):129 points - 4 fields
# OctNode(522220734):129 points - 4 fields
# OctNode(611106):129 points - 4 fields
# OctNode(433326):129 points - 4 fields
# OctNode(077755):129 points - 4 fields
# OctNode(077751):129 points - 4 fields
# OctNode(70167):129 points - 4 fields
# OctNode(70155):129 points - 4 fields
# OctNode(61526):129 points - 4 fields
# OctNode(61523):129 points - 4 fields
# OctNode(52727):129 points - 4 fields
# OctNode(34622):129 points - 4 fields
# OctNode(34575):129 points - 4 fields
# OctNode(34165):129 points - 4 fields
# OctNode(2110):129 points - 4 fields
# OctNode(0331):129 points - 4 fields
# OctNode(61111352):130 points - 4 fields
# OctNode(70506):130 points - 4 fields
# OctNode(70247):130 points - 4 fields
# OctNode(70246):130 points - 4 fields
# OctNode(61342):130 points - 4 fields
# OctNode(52700):130 points - 4 fields
# OctNode(43174):130 points - 4 fields
# OctNode(34625):130 points - 4 fields
# OctNode(34515):130 points - 4 fields
# OctNode(25736):130 points - 4 fields
# OctNode(07512):130 points - 4 fields
# OctNode(3551):130 points - 4 fields
# OctNode(2702):130 points - 4 fields
# OctNode(264):130 points - 4 fields
# OctNode(52222040):131 points - 4 fields
# OctNode(611157):131 points - 4 fields
# OctNode(70442):131 points - 4 fields
# OctNode(70153):131 points - 4 fields
# OctNode(34050):131 points - 4 fields
# OctNode(25341):131 points - 4 fields
# OctNode(25162):131 points - 4 fields
# OctNode(16771):131 points - 4 fields
# OctNode(16750):131 points - 4 fields
# OctNode(07337):131 points - 4 fields
# OctNode(6545):131 points - 4 fields
# OctNode(5071):131 points - 4 fields
# OctNode(4520):131 points - 4 fields
# OctNode(3247):131 points - 4 fields
# OctNode(52222075):132 points - 4 fields
# OctNode(522207):132 points - 4 fields
# OctNode(61417):132 points - 4 fields
# OctNode(52373):132 points - 4 fields
# OctNode(52313):132 points - 4 fields
# OctNode(34242):132 points - 4 fields
# OctNode(25731):132 points - 4 fields
# OctNode(25342):132 points - 4 fields
# OctNode(25053):132 points - 4 fields
# OctNode(7253):132 points - 4 fields
# OctNode(5120):132 points - 4 fields
# OctNode(3006):132 points - 4 fields
# OctNode(2440):132 points - 4 fields
# OctNode(401):132 points - 4 fields
# OctNode(611111703):133 points - 4 fields
# OctNode(61111175):133 points - 4 fields
# OctNode(700016):133 points - 4 fields
# OctNode(611150):133 points - 4 fields
# OctNode(611133):133 points - 4 fields
# OctNode(611104):133 points - 4 fields
# OctNode(166643):133 points - 4 fields
# OctNode(61535):133 points - 4 fields
# OctNode(61437):133 points - 4 fields
# OctNode(52424):133 points - 4 fields
# OctNode(52341):133 points - 4 fields
# OctNode(07555):133 points - 4 fields
# OctNode(07342):133 points - 4 fields
# OctNode(07340):133 points - 4 fields
# OctNode(07314):133 points - 4 fields
# OctNode(07274):133 points - 4 fields
# OctNode(4036):133 points - 4 fields
# OctNode(700000433):134 points - 4 fields
# OctNode(522220602):134 points - 4 fields
# OctNode(700026):134 points - 4 fields
# OctNode(077761):134 points - 4 fields
# OctNode(70165):134 points - 4 fields
# OctNode(61412):134 points - 4 fields
# OctNode(43727):134 points - 4 fields
# OctNode(43160):134 points - 4 fields
# OctNode(34576):134 points - 4 fields
# OctNode(34072):134 points - 4 fields
# OctNode(25737):134 points - 4 fields
# OctNode(16773):134 points - 4 fields
# OctNode(5665):134 points - 4 fields
# OctNode(5337):134 points - 4 fields
# OctNode(4254):134 points - 4 fields
# OctNode(2351):134 points - 4 fields
# OctNode(5222227350):135 points - 4 fields
# OctNode(700044):135 points - 4 fields
# OctNode(522267):135 points - 4 fields
# OctNode(433320):135 points - 4 fields
# OctNode(344442):135 points - 4 fields
# OctNode(70216):135 points - 4 fields
# OctNode(70175):135 points - 4 fields
# OctNode(61536):135 points - 4 fields
# OctNode(61306):135 points - 4 fields
# OctNode(61073):135 points - 4 fields
# OctNode(61007):135 points - 4 fields
# OctNode(16061):135 points - 4 fields
# OctNode(07612):135 points - 4 fields
# OctNode(07524):135 points - 4 fields
# OctNode(07522):135 points - 4 fields
# OctNode(5222226253):136 points - 4 fields
# OctNode(43333072):136 points - 4 fields
# OctNode(077763):136 points - 4 fields
# OctNode(70434):136 points - 4 fields
# OctNode(70243):136 points - 4 fields
# OctNode(61534):136 points - 4 fields
# OctNode(61430):136 points - 4 fields
# OctNode(61307):136 points - 4 fields
# OctNode(43631):136 points - 4 fields
# OctNode(43175):136 points - 4 fields
# OctNode(34657):136 points - 4 fields
# OctNode(16444):136 points - 4 fields
# OctNode(07550):136 points - 4 fields
# OctNode(07513):136 points - 4 fields
# OctNode(07316):136 points - 4 fields
# OctNode(7252):136 points - 4 fields
# OctNode(4530):136 points - 4 fields
# OctNode(433333611):137 points - 4 fields
# OctNode(433333523):137 points - 4 fields
# OctNode(6111104):137 points - 4 fields
# OctNode(61016):137 points - 4 fields
# OctNode(52617):137 points - 4 fields
# OctNode(52427):137 points - 4 fields
# OctNode(43725):137 points - 4 fields
# OctNode(43166):137 points - 4 fields
# OctNode(25163):137 points - 4 fields
# OctNode(07276):137 points - 4 fields
# OctNode(4776):137 points - 4 fields
# OctNode(70445):138 points - 4 fields
# OctNode(70176):138 points - 4 fields
# OctNode(52701):138 points - 4 fields
# OctNode(43715):138 points - 4 fields
# OctNode(34567):138 points - 4 fields
# OctNode(34555):138 points - 4 fields
# OctNode(34553):138 points - 4 fields
# OctNode(25117):138 points - 4 fields
# OctNode(16362):138 points - 4 fields
# OctNode(6526):138 points - 4 fields
# OctNode(5676):138 points - 4 fields
# OctNode(5426):138 points - 4 fields
# OctNode(3523):138 points - 4 fields
# OctNode(620):138 points - 4 fields
# OctNode(4333337350):139 points - 4 fields
# OctNode(433333636):139 points - 4 fields
# OctNode(522274):139 points - 4 fields
# OctNode(522265):139 points - 4 fields
# OctNode(166645):139 points - 4 fields
# OctNode(70504):139 points - 4 fields
# OctNode(70151):139 points - 4 fields
# OctNode(61527):139 points - 4 fields
# OctNode(61435):139 points - 4 fields
# OctNode(61345):139 points - 4 fields
# OctNode(61076):139 points - 4 fields
# OctNode(61070):139 points - 4 fields
# OctNode(52310):139 points - 4 fields
# OctNode(52120):139 points - 4 fields
# OctNode(34624):139 points - 4 fields
# OctNode(25740):139 points - 4 fields
# OctNode(16752):139 points - 4 fields
# OctNode(16435):139 points - 4 fields
# OctNode(16367):139 points - 4 fields
# OctNode(7217):139 points - 4 fields
# OctNode(1225):139 points - 4 fields
# OctNode(5222236062):140 points - 4 fields
# OctNode(522220631):140 points - 4 fields
# OctNode(611137):140 points - 4 fields
# OctNode(611134):140 points - 4 fields
# OctNode(70157):140 points - 4 fields
# OctNode(70077):140 points - 4 fields
# OctNode(56736):140 points - 4 fields
# OctNode(52605):140 points - 4 fields
# OctNode(52333):140 points - 4 fields
# OctNode(43165):140 points - 4 fields
# OctNode(34572):140 points - 4 fields
# OctNode(34411):140 points - 4 fields
# OctNode(34166):140 points - 4 fields
# OctNode(25437):140 points - 4 fields
# OctNode(25410):140 points - 4 fields
# OctNode(25140):140 points - 4 fields
# OctNode(16431):140 points - 4 fields
# OctNode(16072):140 points - 4 fields
# OctNode(07174):140 points - 4 fields
# OctNode(7306):140 points - 4 fields
# OctNode(6713):140 points - 4 fields
# OctNode(2444):140 points - 4 fields
# OctNode(611111412):141 points - 4 fields
# OctNode(522222702):141 points - 4 fields
# OctNode(433331722):141 points - 4 fields
# OctNode(70417):141 points - 4 fields
# OctNode(61357):141 points - 4 fields
# OctNode(61032):141 points - 4 fields
# OctNode(61001):141 points - 4 fields
# OctNode(52420):141 points - 4 fields
# OctNode(52337):141 points - 4 fields
# OctNode(52331):141 points - 4 fields
# OctNode(52127):141 points - 4 fields
# OctNode(43274):141 points - 4 fields
# OctNode(43210):141 points - 4 fields
# OctNode(16434):141 points - 4 fields
# OctNode(6074):141 points - 4 fields
# OctNode(5727):141 points - 4 fields
# OctNode(4537):141 points - 4 fields
# OctNode(611103):142 points - 4 fields
# OctNode(344445):142 points - 4 fields
# OctNode(255550):142 points - 4 fields
# OctNode(61532):142 points - 4 fields
# OctNode(61433):142 points - 4 fields
# OctNode(43216):142 points - 4 fields
# OctNode(43124):142 points - 4 fields
# OctNode(34656):142 points - 4 fields
# OctNode(34077):142 points - 4 fields
# OctNode(25432):142 points - 4 fields
# OctNode(16563):142 points - 4 fields
# OctNode(16060):142 points - 4 fields
# OctNode(07654):142 points - 4 fields
# OctNode(07630):142 points - 4 fields
# OctNode(6714):142 points - 4 fields
# OctNode(0175):142 points - 4 fields
# OctNode(522223401):143 points - 4 fields
# OctNode(522222500):143 points - 4 fields
# OctNode(522222411):143 points - 4 fields
# OctNode(433333412):143 points - 4 fields
# OctNode(43333346):143 points - 4 fields
# OctNode(166644):143 points - 4 fields
# OctNode(70162):143 points - 4 fields
# OctNode(61302):143 points - 4 fields
# OctNode(52421):143 points - 4 fields
# OctNode(43701):143 points - 4 fields
# OctNode(34557):143 points - 4 fields
# OctNode(34510):143 points - 4 fields
# OctNode(25430):143 points - 4 fields
# OctNode(25352):143 points - 4 fields
# OctNode(25160):143 points - 4 fields
# OctNode(07632):143 points - 4 fields
# OctNode(07616):143 points - 4 fields
# OctNode(7521):143 points - 4 fields
# OctNode(5331):143 points - 4 fields
# OctNode(3557):143 points - 4 fields
# OctNode(3147):143 points - 4 fields
# OctNode(0525):143 points - 4 fields
# OctNode(700000521):144 points - 4 fields
# OctNode(433333507):144 points - 4 fields
# OctNode(522231):144 points - 4 fields
# OctNode(70432):144 points - 4 fields
# OctNode(70425):144 points - 4 fields
# OctNode(70207):144 points - 4 fields
# OctNode(70154):144 points - 4 fields
# OctNode(70111):144 points - 4 fields
# OctNode(52374):144 points - 4 fields
# OctNode(43636):144 points - 4 fields
# OctNode(34073):144 points - 4 fields
# OctNode(34056):144 points - 4 fields
# OctNode(16757):144 points - 4 fields
# OctNode(16722):144 points - 4 fields
# OctNode(07521):144 points - 4 fields
# OctNode(07362):144 points - 4 fields
# OctNode(07360):144 points - 4 fields
# OctNode(07275):144 points - 4 fields
# OctNode(5421):144 points - 4 fields
# OctNode(61111156):145 points - 4 fields
# OctNode(611130):145 points - 4 fields
# OctNode(433322):145 points - 4 fields
# OctNode(70174):145 points - 4 fields
# OctNode(70164):145 points - 4 fields
# ...
# OctNode(0735):2610 points - 4 fields
# OctNode(7041):2634 points - 4 fields
# OctNode(3464):2645 points - 4 fields
# OctNode(0767):2646 points - 4 fields
# OctNode(52222162):2661 points - 4 fields
# OctNode(43333253):2680 points - 4 fields
# OctNode(61111173):2684 points - 4 fields
# OctNode(652):2687 points - 4 fields
# OctNode(0756):2691 points - 4 fields
# OctNode(4373):2694 points - 4 fields
# OctNode(6151):2697 points - 4 fields
# OctNode(43333172):2705 points - 4 fields
# OctNode(5263):2722 points - 4 fields
# OctNode(3404):2724 points - 4 fields
# OctNode(177):2729 points - 4 fields
# OctNode(0737):2732 points - 4 fields
# OctNode(3454):2738 points - 4 fields
# OctNode(265):2738 points - 4 fields
# OctNode(425):2739 points - 4 fields
# OctNode(411):2745 points - 4 fields
# OctNode(2515):2746 points - 4 fields
# OctNode(4333321):2747 points - 4 fields
# OctNode(4323):2750 points - 4 fields
# OctNode(7020):2751 points - 4 fields
# OctNode(61111143):2758 points - 4 fields
# OctNode(6101):2762 points - 4 fields
# OctNode(3447):2768 points - 4 fields
# OctNode(7014):2770 points - 4 fields
# OctNode(355):2775 points - 4 fields
# OctNode(1624):2780 points - 4 fields
# OctNode(170):2781 points - 4 fields
# OctNode(0753):2793 points - 4 fields
# OctNode(52222260):2800 points - 4 fields
# OctNode(5236):2804 points - 4 fields
# OctNode(7007):2806 points - 4 fields
# OctNode(52222261):2813 points - 4 fields
# OctNode(6111105):2820 points - 4 fields
# OctNode(2545):2832 points - 4 fields
# OctNode(6131):2833 points - 4 fields
# OctNode(6116):2834 points - 4 fields
# OctNode(52222340):2839 points - 4 fields
# OctNode(4334):2840 points - 4 fields
# OctNode(374):2842 points - 4 fields
# OctNode(2575):2844 points - 4 fields
# OctNode(52222061):2845 points - 4 fields
# OctNode(125):2845 points - 4 fields
# OctNode(4313):2848 points - 4 fields
# OctNode(056):2856 points - 4 fields
# OctNode(1676):2859 points - 4 fields
# OctNode(7040):2862 points - 4 fields
# OctNode(5202):2863 points - 4 fields
# OctNode(621):2865 points - 4 fields
# OctNode(1642):2869 points - 4 fields
# OctNode(07777):2885 points - 4 fields
# OctNode(716):2892 points - 4 fields
# OctNode(3442):2895 points - 4 fields
# OctNode(061):2904 points - 4 fields
# OctNode(52222241):2919 points - 4 fields
# OctNode(143):2921 points - 4 fields
# OctNode(04):2921 points - 4 fields
# OctNode(655):2926 points - 4 fields
# OctNode(607):2939 points - 4 fields
# OctNode(1626):2949 points - 4 fields
# OctNode(724):2952 points - 4 fields
# OctNode(2552):2958 points - 4 fields
# OctNode(0770):2962 points - 4 fields
# OctNode(027):2962 points - 4 fields
# OctNode(477):2977 points - 4 fields
# OctNode(205):2981 points - 4 fields
# OctNode(40):2989 points - 4 fields
# OctNode(522202):2994 points - 4 fields
# OctNode(721):2997 points - 4 fields
# OctNode(360):3004 points - 4 fields
# OctNode(217):3023 points - 4 fields
# OctNode(76):3026 points - 4 fields
# OctNode(52222271):3029 points - 4 fields
# OctNode(5225):3030 points - 4 fields
# OctNode(566):3043 points - 4 fields
# OctNode(4333323):3052 points - 4 fields
# OctNode(503):3060 points - 4 fields
# OctNode(421):3067 points - 4 fields
# OctNode(5232):3069 points - 4 fields
# OctNode(43333351):3080 points - 4 fields
# OctNode(7003):3084 points - 4 fields
# OctNode(1661):3084 points - 4 fields
# OctNode(6114):3091 points - 4 fields
# OctNode(61111171):3093 points - 4 fields
# OctNode(416):3104 points - 4 fields
# OctNode(361):3114 points - 4 fields
# OctNode(417):3115 points - 4 fields
# OctNode(065):3115 points - 4 fields
# OctNode(31):3115 points - 4 fields
# OctNode(743):3121 points - 4 fields
# OctNode(653):3123 points - 4 fields
# OctNode(2553):3133 points - 4 fields
# OctNode(270):3134 points - 4 fields
# OctNode(52222242):3138 points - 4 fields
# OctNode(43333343):3142 points - 4 fields
# OctNode(0757):3145 points - 4 fields
# OctNode(412):3149 points - 4 fields
# OctNode(52222240):3154 points - 4 fields
# OctNode(70000040):3160 points - 4 fields
# OctNode(216):3169 points - 4 fields
# OctNode(70000060):3186 points - 4 fields
# OctNode(61111152):3188 points - 4 fields
# OctNode(034):3188 points - 4 fields
# OctNode(1663):3190 points - 4 fields
# OctNode(70000050):3197 points - 4 fields
# OctNode(23):3201 points - 4 fields
# OctNode(352):3207 points - 4 fields
# OctNode(43333361):3212 points - 4 fields
# OctNode(7010):3212 points - 4 fields
# OctNode(1646):3215 points - 4 fields
# OctNode(561):3220 points - 4 fields
# OctNode(471):3227 points - 4 fields
# OctNode(506):3249 points - 4 fields
# OctNode(4336):3267 points - 4 fields
# OctNode(4335):3274 points - 4 fields
# OctNode(534):3280 points - 4 fields
# OctNode(7000014):3288 points - 4 fields
# OctNode(463):3296 points - 4 fields
# OctNode(4330):3308 points - 4 fields
# OctNode(350):3323 points - 4 fields
# OctNode(147):3324 points - 4 fields
# OctNode(13):3324 points - 4 fields
# OctNode(43333372):3329 points - 4 fields
# OctNode(214):3331 points - 4 fields
# OctNode(43333352):3334 points - 4 fields
# OctNode(172):3334 points - 4 fields
# OctNode(6117):3339 points - 4 fields
# OctNode(365):3345 points - 4 fields
# OctNode(15):3361 points - 4 fields
# OctNode(01):3367 points - 4 fields
# OctNode(6112):3373 points - 4 fields
# OctNode(742):3375 points - 4 fields
# OctNode(52222243):3394 points - 4 fields
# OctNode(127):3419 points - 4 fields
# OctNode(61111150):3422 points - 4 fields
# OctNode(433313):3449 points - 4 fields
# OctNode(641):3462 points - 4 fields
# OctNode(2550):3465 points - 4 fields
# OctNode(560):3467 points - 4 fields
# OctNode(43333353):3469 points - 4 fields
# OctNode(2556):3475 points - 4 fields
# OctNode(73):3483 points - 4 fields
# OctNode(0772):3489 points - 4 fields
# OctNode(67):3499 points - 4 fields
# OctNode(305):3501 points - 4 fields
# OctNode(247):3531 points - 4 fields
# OctNode(7006):3535 points - 4 fields
# OctNode(0774):3538 points - 4 fields
# OctNode(634):3546 points - 4 fields
# OctNode(54):3550 points - 4 fields
# OctNode(51):3552 points - 4 fields
# OctNode(142):3553 points - 4 fields
# OctNode(307):3573 points - 4 fields
# OctNode(3440):3578 points - 4 fields
# OctNode(470):3599 points - 4 fields
# OctNode(745):3616 points - 4 fields
# OctNode(5224):3625 points - 4 fields
# OctNode(174):3627 points - 4 fields
# OctNode(243):3629 points - 4 fields
# OctNode(70000041):3635 points - 4 fields
# OctNode(271):3636 points - 4 fields
# OctNode(053):3647 points - 4 fields
# OctNode(61111153):3656 points - 4 fields
# OctNode(6111116):3687 points - 4 fields
# OctNode(611113):3687 points - 4 fields
# OctNode(427):3699 points - 4 fields
# OctNode(700001):3701 points - 4 fields
# OctNode(530):3717 points - 4 fields
# OctNode(567):3721 points - 4 fields
# OctNode(52222362):3734 points - 4 fields
# OctNode(603):3751 points - 4 fields
# OctNode(43333370):3756 points - 4 fields
# OctNode(635):3756 points - 4 fields
# OctNode(5222216):3786 points - 4 fields
# OctNode(32):3789 points - 4 fields
# OctNode(0771):3795 points - 4 fields
# OctNode(741):3807 points - 4 fields
# OctNode(70000051):3830 points - 4 fields
# OctNode(306):3837 points - 4 fields
# OctNode(10):3837 points - 4 fields
# OctNode(714):3854 points - 4 fields
# OctNode(036):3865 points - 4 fields
# OctNode(146):3869 points - 4 fields
# OctNode(3446):3877 points - 4 fields
# OctNode(1660):3882 points - 4 fields
# OctNode(26):3883 points - 4 fields
# OctNode(1665):3884 points - 4 fields
# OctNode(43333373):3894 points - 4 fields
# OctNode(274):3897 points - 4 fields
# OctNode(7000007):3916 points - 4 fields
# OctNode(52220):3937 points - 4 fields
# OctNode(43333371):3938 points - 4 fields
# OctNode(536):3941 points - 4 fields
# OctNode(4333316):3956 points - 4 fields
# OctNode(75):3959 points - 4 fields
# OctNode(52222262):3966 points - 4 fields
# OctNode(52222272):3967 points - 4 fields
# OctNode(61111151):3989 points - 4 fields
# OctNode(3445):4010 points - 4 fields
# OctNode(5221):4031 points - 4 fields
# OctNode(45):4039 points - 4 fields
# OctNode(563):4043 points - 4 fields
# OctNode(70000061):4048 points - 4 fields
# OctNode(4333325):4049 points - 4 fields
# OctNode(2557):4052 points - 4 fields
# OctNode(502):4054 points - 4 fields
# OctNode(364):4056 points - 4 fields
# OctNode(630):4099 points - 4 fields
# OctNode(063):4102 points - 4 fields
# OctNode(52222273):4128 points - 4 fields
# OctNode(472):4137 points - 4 fields
# OctNode(02):4141 points - 4 fields
# OctNode(62):4165 points - 4 fields
# OctNode(2551):4215 points - 4 fields
# OctNode(304):4250 points - 4 fields
# OctNode(1662):4264 points - 4 fields
# OctNode(52222270):4268 points - 4 fields
# OctNode(161):4287 points - 4 fields
# OctNode(720):4297 points - 4 fields
# OctNode(5222205):4305 points - 4 fields
# OctNode(20):4305 points - 4 fields
# OctNode(605):4307 points - 4 fields
# OctNode(712):4308 points - 4 fields
# OctNode(7005):4311 points - 4 fields
# OctNode(5227):4320 points - 4 fields
# OctNode(035):4325 points - 4 fields
# OctNode(2554):4351 points - 4 fields
# OctNode(356):4368 points - 4 fields
# OctNode(176):4396 points - 4 fields
# OctNode(707):4400 points - 4 fields
# OctNode(4333327):4405 points - 4 fields
# OctNode(126):4408 points - 4 fields
# OctNode(52222360):4441 points - 4 fields
# OctNode(43331):4446 points - 4 fields
# OctNode(52222252):4463 points - 4 fields
# OctNode(57):4482 points - 4 fields
# OctNode(0773):4487 points - 4 fields
# OctNode(562):4492 points - 4 fields
# OctNode(0776):4501 points - 4 fields
# OctNode(37):4504 points - 4 fields
# OctNode(434):4517 points - 4 fields
# OctNode(522221):4529 points - 4 fields
# OctNode(6110):4536 points - 4 fields
# OctNode(057):4542 points - 4 fields
# OctNode(413):4551 points - 4 fields
# OctNode(6115):4562 points - 4 fields
# OctNode(124):4573 points - 4 fields
# OctNode(215):4603 points - 4 fields
# OctNode(601):4605 points - 4 fields
# OctNode(423):4653 points - 4 fields
# OctNode(70000052):4674 points - 4 fields
# OctNode(343):4677 points - 4 fields
# OctNode(473):4698 points - 4 fields
# OctNode(7002):4711 points - 4 fields
# OctNode(64):4726 points - 4 fields
# OctNode(740):4741 points - 4 fields
# OctNode(067):4743 points - 4 fields
# OctNode(241):4757 points - 4 fields
# OctNode(4332):4774 points - 4 fields
# OctNode(525):4774 points - 4 fields
# OctNode(70000042):4779 points - 4 fields
# OctNode(6113):4788 points - 4 fields
# OctNode(70000043):4806 points - 4 fields
# OctNode(4331):4815 points - 4 fields
# OctNode(631):4830 points - 4 fields
# OctNode(52222263):4839 points - 4 fields
# OctNode(650):4849 points - 4 fields
# OctNode(46):4898 points - 4 fields
# OctNode(5226):4904 points - 4 fields
# OctNode(245):4905 points - 4 fields
# OctNode(275):4941 points - 4 fields
# OctNode(354):4985 points - 4 fields
# OctNode(070):4995 points - 4 fields
# OctNode(616):5020 points - 4 fields
# OctNode(7004):5050 points - 4 fields
# OctNode(5220):5059 points - 4 fields
# OctNode(0775):5078 points - 4 fields
# OctNode(1667):5084 points - 4 fields
# OctNode(4337):5103 points - 4 fields
# OctNode(651):5147 points - 4 fields
# OctNode(037):5231 points - 4 fields
# OctNode(4333303):5298 points - 4 fields
# OctNode(5222207):5309 points - 4 fields
# OctNode(5223):5314 points - 4 fields
# OctNode(7001):5317 points - 4 fields
# OctNode(532):5317 points - 4 fields
# OctNode(703):5362 points - 4 fields
# OctNode(1664):5521 points - 4 fields
# OctNode(435):5563 points - 4 fields
# OctNode(252):5586 points - 4 fields
# OctNode(706):5659 points - 4 fields
# OctNode(5222234):5731 points - 4 fields
# OctNode(430):5802 points - 4 fields
# OctNode(710):5821 points - 4 fields
# OctNode(611110):5835 points - 4 fields
# OctNode(617):5863 points - 4 fields
# OctNode(074):6030 points - 4 fields
# OctNode(342):6069 points - 4 fields
# OctNode(524):6132 points - 4 fields
# OctNode(4333317):6228 points - 4 fields
# OctNode(163):6413 points - 4 fields
# OctNode(347):6435 points - 4 fields
# OctNode(521):6462 points - 4 fields
# OctNode(256):6490 points - 4 fields
# OctNode(612):6510 points - 4 fields
# OctNode(3444):6534 points - 4 fields
# OctNode(165):6633 points - 4 fields
# OctNode(072):6841 points - 4 fields
# OctNode(341):6871 points - 4 fields
# OctNode(705):7003 points - 4 fields
# OctNode(6111114):7054 points - 4 fields
# OctNode(4333334):7100 points - 4 fields
# OctNode(250):7186 points - 4 fields
# OctNode(5222206):7240 points - 4 fields
# OctNode(2555):7340 points - 4 fields
# OctNode(071):7413 points - 4 fields
# OctNode(436):7484 points - 4 fields
# OctNode(253):7558 points - 4 fields
# OctNode(4333336):7637 points - 4 fields
# OctNode(614):7726 points - 4 fields
# OctNode(527):7800 points - 4 fields
# OctNode(160):7941 points - 4 fields
# OctNode(1666):8099 points - 4 fields
# OctNode(6111117):8152 points - 4 fields
# OctNode(7000006):8323 points - 4 fields
# OctNode(5222225):8677 points - 4 fields
# OctNode(433330):8819 points - 4 fields
# OctNode(702):9021 points - 4 fields
# OctNode(437):9270 points - 4 fields
# OctNode(0777):9331 points - 4 fields
# OctNode(4333335):9524 points - 4 fields
# OctNode(432):9771 points - 4 fields
# OctNode(5222224):9793 points - 4 fields
# OctNode(5222236):9932 points - 4 fields
# OctNode(340):9970 points - 4 fields
# OctNode(613):10128 points - 4 fields
# OctNode(346):10137 points - 4 fields
# OctNode(526):10211 points - 4 fields
# OctNode(076):10224 points - 4 fields
# OctNode(615):10256 points - 4 fields
# OctNode(704):10395 points - 4 fields
# OctNode(610):10423 points - 4 fields
# OctNode(431):10543 points - 4 fields
# OctNode(345):10731 points - 4 fields
# OctNode(257):10740 points - 4 fields
# OctNode(251):10789 points - 4 fields
# OctNode(162):10882 points - 4 fields
# OctNode(520):10915 points - 4 fields
# OctNode(254):10937 points - 4 fields
# OctNode(167):10944 points - 4 fields
# OctNode(073):11136 points - 4 fields
# OctNode(5222226):11537 points - 4 fields
# OctNode(164):11649 points - 4 fields
# OctNode(6111115):11744 points - 4 fields
# OctNode(523):11824 points - 4 fields
# OctNode(701):11978 points - 4 fields
# OctNode(4333337):12063 points - 4 fields
# OctNode(72):12087 points - 4 fields
# OctNode(075):12133 points - 4 fields
# OctNode(7000005):12546 points - 4 fields
# OctNode(05):12601 points - 4 fields
# OctNode(433332):12635 points - 4 fields
# OctNode(50):12999 points - 4 fields
# OctNode(36):13244 points - 4 fields
# OctNode(7000004):13556 points - 4 fields
# OctNode(5222227):13613 points - 4 fields
# OctNode(14):13785 points - 4 fields
# OctNode(42):13915 points - 4 fields
# OctNode(21):14525 points - 4 fields
# OctNode(522223):15056 points - 4 fields
# OctNode(06):15095 points - 4 fields
# OctNode(27):15327 points - 4 fields
# OctNode(17):15362 points - 4 fields
# OctNode(60):15467 points - 4 fields
# OctNode(12):15572 points - 4 fields
# OctNode(41):15798 points - 4 fields
# OctNode(433331):15940 points - 4 fields
# OctNode(30):16116 points - 4 fields
# OctNode(63):16753 points - 4 fields
# OctNode(35):16772 points - 4 fields
# OctNode(03):17147 points - 4 fields
# OctNode(65):17517 points - 4 fields
# OctNode(53):17556 points - 4 fields
# OctNode(47):17597 points - 4 fields
# OctNode(74):17658 points - 4 fields
# OctNode(24):17683 points - 4 fields
# OctNode(71):17772 points - 4 fields
# OctNode(56):18802 points - 4 fields
# OctNode(522220):19244 points - 4 fields
# OctNode(344):21506 points - 4 fields
# OctNode(255):25989 points - 4 fields
# OctNode(611111):29305 points - 4 fields
# OctNode(166):30008 points - 4 fields
# OctNode(077):30181 points - 4 fields
# OctNode(433333):34130 points - 4 fields
# OctNode(700000):35718 points - 4 fields
# OctNode(61111):38080 points - 4 fields
# OctNode(70000):40558 points - 4 fields
# OctNode(522222):41134 points - 4 fields
# OctNode(6111):45256 points - 4 fields
# OctNode(7000):47548 points - 4 fields
# OctNode(611):64779 points - 4 fields
# OctNode(700):69362 points - 4 fields
# OctNode(34):69396 points - 4 fields
# OctNode(43333):69432 points - 4 fields
# OctNode(52222):78109 points - 4 fields
# OctNode(25):78275 points - 4 fields
# OctNode(4333):78416 points - 4 fields
# OctNode(16):81757 points - 4 fields
# OctNode(07):81953 points - 4 fields
# OctNode(5222):87281 points - 4 fields
# OctNode(433):98797 points - 4 fields
# OctNode(522):110564 points - 4 fields
# OctNode(61):113705 points - 4 fields
# OctNode(70):116180 points - 4 fields
# OctNode(3):121057 points - 4 fields
# OctNode(1):131085 points - 4 fields
# OctNode(0):131312 points - 4 fields
# OctNode(2):131321 points - 4 fields
# OctNode(43):144747 points - 4 fields
# OctNode(52):161682 points - 4 fields
# OctNode(7):168283 points - 4 fields
# OctNode(6):169929 points - 4 fields
# OctNode(4):198108 points - 4 fields
# OctNode(5):216870 points - 4 fields
# OctNode():1260965 points - 4 fields

# %%
foo = octree.node_list[0]
foo.fields
# Out:
# {'Masses': 0.005686212549335323,
#  'com_x': 0.11179892445819087,
#  'com_y': 0.8268328181610287,
#  'com_z': -0.38125960567559114}

# %%
np.sum(masses[:,None]*coords,axis=0)
# Out:
# array([ 0.05490658,  0.40416597, -0.18240251])

# %%
masses.size
# Out:
# 483

# %%
coords = np.array(octree.node_list[0].raw_coords)
masses = np.array(foo.raw_fields)[:,0]
